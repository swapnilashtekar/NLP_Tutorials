# %%
### This should go into __init__()
import nltk
from nltk import word_tokenize, sent_tokenize
import gensim
from gensim.models.word2vec import Word2Vec
from sklearn.manifold import TSNE
import pandas as pd
from bokeh.io import output_notebook
from bokeh.plotting import show, figure
# %matplotlib inline

# %%
nltk.download('punkt') # English-language sentence tokenizer (not all periods end sentences; not all sentences start with a capital letter)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/swapnilashtekar/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# Loading Data

# %%
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     /Users/swapnilashtekar/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# True

# %%
from nltk.corpus import gutenberg

# %%
len(gutenberg.fileids()), gutenberg.fileids()
# Out:
# (18,
#  [u'austen-emma.txt',
#   u'austen-persuasion.txt',
#   u'austen-sense.txt',
#   u'bible-kjv.txt',
#   u'blake-poems.txt',
#   u'bryant-stories.txt',
#   u'burgess-busterbrown.txt',
#   u'carroll-alice.txt',
#   u'chesterton-ball.txt',
#   u'chesterton-brown.txt',
#   u'chesterton-thursday.txt',
#   u'edgeworth-parents.txt',
#   u'melville-moby_dick.txt',
#   u'milton-paradise.txt',
#   u'shakespeare-caesar.txt',
#   u'shakespeare-hamlet.txt',
#   u'shakespeare-macbeth.txt',
#   u'whitman-leaves.txt'])

# %% [markdown]
# Tokenizing text

# %%
gbergSentTokens = sent_tokenize(gutenberg.raw())

# %%
gbergSentTokens[0:5], gbergSentTokens[1]
# Out:
# ([u'[Emma by Jane Austen 1816]\n\nVOLUME I\n\nCHAPTER I\n\n\nEmma Woodhouse, handsome, clever, and rich, with a comfortable home\nand happy disposition, seemed to unite some of the best blessings\nof existence; and had lived nearly twenty-one years in the world\nwith very little to distress or vex her.',
#   u"She was the youngest of the two daughters of a most affectionate,\nindulgent father; and had, in consequence of her sister's marriage,\nbeen mistress of his house from a very early period.",
#   u'Her mother\nhad died too long ago for her to have more than an indistinct\nremembrance of her caresses; and her place had been supplied\nby an excellent woman as governess, who had fallen little short\nof a mother in affection.',
#   u"Sixteen years had Miss Taylor been in Mr. Woodhouse's family,\nless as a governess than a friend, very fond of both daughters,\nbut particularly of Emma.",
#   u'Between _them_ it was more the intimacy\nof sisters.'],
#  u"She was the youngest of the two daughters of a most affectionate,\nindulgent father; and had, in consequence of her sister's marriage,\nbeen mistress of his house from a very early period.")

# %%
word_tokenize(gbergSentTokens[1])
# Out:
# [u'She',
#  u'was',
#  u'the',
#  u'youngest',
#  u'of',
#  u'the',
#  u'two',
#  u'daughters',
#  u'of',
#  u'a',
#  u'most',
#  u'affectionate',
#  u',',
#  u'indulgent',
#  u'father',
#  u';',
#  u'and',
#  u'had',
#  u',',
#  u'in',
#  u'consequence',
#  u'of',
#  u'her',
#  u'sister',
#  u"'s",
#  u'marriage',
#  u',',
#  u'been',
#  u'mistress',
#  u'of',
#  u'his',
#  u'house',
#  u'from',
#  u'a',
#  u'very',
#  u'early',
#  u'period',
#  u'.']

# %%
word_tokenize(gbergSentTokens[1])[14]
# Out:
# u'father'

# %%
# a convenient method that handles newlines, as well as tokenizing sentences and words in one shot
gbergSents = gutenberg.sents()

# %%
gbergSents[0:5]
# Out:
# [[u'[', u'Emma', u'by', u'Jane', u'Austen', u'1816', u']'],
#  [u'VOLUME', u'I'],
#  [u'CHAPTER', u'I'],
#  [u'Emma',
#   u'Woodhouse',
#   u',',
#   u'handsome',
#   u',',
#   u'clever',
#   u',',
#   u'and',
#   u'rich',
#   u',',
#   u'with',
#   u'a',
#   u'comfortable',
#   u'home',
#   u'and',
#   u'happy',
#   u'disposition',
#   u',',
#   u'seemed',
#   u'to',
#   u'unite',
#   u'some',
#   u'of',
#   u'the',
#   u'best',
#   u'blessings',
#   u'of',
#   u'existence',
#   u';',
#   u'and',
#   u'had',
#   u'lived',
#   u'nearly',
#   u'twenty',
#   u'-',
#   u'one',
#   u'years',
#   u'in',
#   u'the',
#   u'world',
#   u'with',
#   u'very',
#   u'little',
#   u'to',
#   u'distress',
#   u'or',
#   u'vex',
#   u'her',
#   u'.'],
#  [u'She',
#   u'was',
#   u'the',
#   u'youngest',
#   u'of',
#   u'the',
#   u'two',
#   u'daughters',
#   u'of',
#   u'a',
#   u'most',
#   u'affectionate',
#   u',',
#   u'indulgent',
#   u'father',
#   u';',
#   u'and',
#   u'had',
#   u',',
#   u'in',
#   u'consequence',
#   u'of',
#   u'her',
#   u'sister',
#   u"'",
#   u's',
#   u'marriage',
#   u',',
#   u'been',
#   u'mistress',
#   u'of',
#   u'his',
#   u'house',
#   u'from',
#   u'a',
#   u'very',
#   u'early',
#   u'period',
#   u'.']]

# %%
gbergSents[4]
# Out:
# [u'She',
#  u'was',
#  u'the',
#  u'youngest',
#  u'of',
#  u'the',
#  u'two',
#  u'daughters',
#  u'of',
#  u'a',
#  u'most',
#  u'affectionate',
#  u',',
#  u'indulgent',
#  u'father',
#  u';',
#  u'and',
#  u'had',
#  u',',
#  u'in',
#  u'consequence',
#  u'of',
#  u'her',
#  u'sister',
#  u"'",
#  u's',
#  u'marriage',
#  u',',
#  u'been',
#  u'mistress',
#  u'of',
#  u'his',
#  u'house',
#  u'from',
#  u'a',
#  u'very',
#  u'early',
#  u'period',
#  u'.']

# %%
gbergSents[4][14]
# Out:
# u'father'

# %%
# another convenient method that we don't immediately need: 
gutenberg.words(), len(gutenberg.words())
# Out:
# ([u'[', u'Emma', u'by', u'Jane', u'Austen', u'1816', ...], 2621613)

# %% [markdown]
# Running Word2Vec

# %%
model = Word2Vec(sentences=gbergSents, size=64, sg=1, window=10, min_count=5, seed=42, workers=8)

# %% [markdown]
# Saving model for future use

# %%
model.save('raw_gutenberg_model.w2v')

# %%
#close, but not quite; distinctly in female direction: 
model.most_similar(positive=['father', 'woman'], negative=['man'])
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel/__main__.py:2: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   from ipykernel import kernelapp as app
# [(u'sister', 0.7960052490234375),
#  (u'mother', 0.7806724905967712),
#  (u'wife', 0.7582480311393738),
#  (u'daughter', 0.7580640316009521),
#  (u'husband', 0.7462586760520935),
#  (u'Sarai', 0.7193201184272766),
#  (u'Sarah', 0.7175078392028809),
#  (u'daughters', 0.710322380065918),
#  (u'conceived', 0.6978969573974609),
#  (u'Rachel', 0.6939716935157776)]

# %%
model.most_similar(positive=['husband', 'woman'], negative=['man'])
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel/__main__.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   if __name__ == '__main__':
# [(u'wife', 0.7287250757217407),
#  (u'sister', 0.7060500383377075),
#  (u'conceived', 0.6868337392807007),
#  (u'child', 0.6771140098571777),
#  (u'mother', 0.660914421081543),
#  (u'daughter', 0.6443178653717041),
#  (u'widow', 0.6388698816299438),
#  (u'maid', 0.6367749571800232),
#  (u'daughters', 0.6237233281135559),
#  (u'womb', 0.6213292479515076)]

# %% [markdown]
# Reducing word vector dimensionality with t-SNE

# %%
model.wv.vocab
# Out:
# {u'realms': <gensim.models.keyedvectors.Vocab at 0x109177510>,
#  u'Doeg': <gensim.models.keyedvectors.Vocab at 0x1091f07d0>,
#  u'both': <gensim.models.keyedvectors.Vocab at 0x110c38f10>,
#  u'yellow': <gensim.models.keyedvectors.Vocab at 0x111f42210>,
#  u'four': <gensim.models.keyedvectors.Vocab at 0x1091f0850>,
#  u'woods': <gensim.models.keyedvectors.Vocab at 0x10f9f7b50>,
#  u'hanging': <gensim.models.keyedvectors.Vocab at 0x1133c0490>,
#  u'conjuring': <gensim.models.keyedvectors.Vocab at 0x111f42290>,
#  u'woody': <gensim.models.keyedvectors.Vocab at 0x1133c0450>,
#  u'Harriet': <gensim.models.keyedvectors.Vocab at 0x111ccee10>,
#  u'marching': <gensim.models.keyedvectors.Vocab at 0x111f27610>,
#  u'Caes': <gensim.models.keyedvectors.Vocab at 0x1133c0810>,
#  u'Foundation': <gensim.models.keyedvectors.Vocab at 0x111e103d0>,
#  u'euery': <gensim.models.keyedvectors.Vocab at 0x1091f09d0>,
#  u'eligible': <gensim.models.keyedvectors.Vocab at 0x110ba3690>,
#  u'Libnah': <gensim.models.keyedvectors.Vocab at 0x1091f0a10>,
#  u'Starting': <gensim.models.keyedvectors.Vocab at 0x110be0d50>,
#  u'scold': <gensim.models.keyedvectors.Vocab at 0x1133c0410>,
#  u'wheeled': <gensim.models.keyedvectors.Vocab at 0x111f7f950>,
#  u'mistakes': <gensim.models.keyedvectors.Vocab at 0x1092a07d0>,
#  u'Vengeance': <gensim.models.keyedvectors.Vocab at 0x111fbbad0>,
#  u'Western': <gensim.models.keyedvectors.Vocab at 0x1133c0350>,
#  u'buck': <gensim.models.keyedvectors.Vocab at 0x110cfe650>,
#  u'lore': <gensim.models.keyedvectors.Vocab at 0x110ba36d0>,
#  u'portentous': <gensim.models.keyedvectors.Vocab at 0x111ebe2d0>,
#  u'meadows': <gensim.models.keyedvectors.Vocab at 0x1091f0a50>,
#  u'sinking': <gensim.models.keyedvectors.Vocab at 0x1091f0a90>,
#  u'treasuries': <gensim.models.keyedvectors.Vocab at 0x1091fb750>,
#  u'slothful': <gensim.models.keyedvectors.Vocab at 0x1133c0090>,
#  u'nights': <gensim.models.keyedvectors.Vocab at 0x110b82050>,
#  u'Nebuchadrezzar': <gensim.models.keyedvectors.Vocab at 0x1091f0ad0>,
#  u'oceans': <gensim.models.keyedvectors.Vocab at 0x117644e10>,
#  u'figs': <gensim.models.keyedvectors.Vocab at 0x111f42310>,
#  u'fur': <gensim.models.keyedvectors.Vocab at 0x1091775d0>,
#  u'stabbed': <gensim.models.keyedvectors.Vocab at 0x1091f0b10>,
#  u'bringing': <gensim.models.keyedvectors.Vocab at 0x1133c03d0>,
#  u'Reddy': <gensim.models.keyedvectors.Vocab at 0x110ba3750>,
#  u'Goshen': <gensim.models.keyedvectors.Vocab at 0x1133c0390>,
#  u'wooded': <gensim.models.keyedvectors.Vocab at 0x1133c04d0>,
#  u'recollections': <gensim.models.keyedvectors.Vocab at 0x1091f0bd0>,
#  u'uttering': <gensim.models.keyedvectors.Vocab at 0x1091f0c10>,
#  u'prize': <gensim.models.keyedvectors.Vocab at 0x111f42390>,
#  u'Less': <gensim.models.keyedvectors.Vocab at 0x1091f0c50>,
#  u'wooden': <gensim.models.keyedvectors.Vocab at 0x1133c0550>,
#  u'brutish': <gensim.models.keyedvectors.Vocab at 0x111c97790>,
#  u'Lachish': <gensim.models.keyedvectors.Vocab at 0x111f423d0>,
#  u'crotch': <gensim.models.keyedvectors.Vocab at 0x1133c05d0>,
#  u'succession': <gensim.models.keyedvectors.Vocab at 0x111f42410>,
#  u'Tuesday': <gensim.models.keyedvectors.Vocab at 0x110c69c90>,
#  u'Paul': <gensim.models.keyedvectors.Vocab at 0x1091f0d10>,
#  u'straight': <gensim.models.keyedvectors.Vocab at 0x10922c8d0>,
#  u'ornamental': <gensim.models.keyedvectors.Vocab at 0x1091f0d50>,
#  u'garraun': <gensim.models.keyedvectors.Vocab at 0x1133c0610>,
#  u'sooty': <gensim.models.keyedvectors.Vocab at 0x1133c0650>,
#  u'nigh': <gensim.models.keyedvectors.Vocab at 0x110ba37d0>,
#  u'clover': <gensim.models.keyedvectors.Vocab at 0x1091b3a50>,
#  u'cordially': <gensim.models.keyedvectors.Vocab at 0x110ba3850>,
#  u'preface': <gensim.models.keyedvectors.Vocab at 0x1091f08d0>,
#  u'mail': <gensim.models.keyedvectors.Vocab at 0x110c7a6d0>,
#  u'pulse': <gensim.models.keyedvectors.Vocab at 0x110ba3890>,
#  u'tires': <gensim.models.keyedvectors.Vocab at 0x110ba38d0>,
#  u'rampart': <gensim.models.keyedvectors.Vocab at 0x111f42450>,
#  u'second': <gensim.models.keyedvectors.Vocab at 0x110ba3950>,
#  u'sooth': <gensim.models.keyedvectors.Vocab at 0x1133c0690>,
#  u'valiant': <gensim.models.keyedvectors.Vocab at 0x1091f0dd0>,
#  u'sternly': <gensim.models.keyedvectors.Vocab at 0x110ce8a10>,
#  u'sailed': <gensim.models.keyedvectors.Vocab at 0x1091f0e10>,
#  u'scraped': <gensim.models.keyedvectors.Vocab at 0x1133c06d0>,
#  u'Townsend': <gensim.models.keyedvectors.Vocab at 0x111f424d0>,
#  u'bolts': <gensim.models.keyedvectors.Vocab at 0x110cdd710>,
#  u'driven': <gensim.models.keyedvectors.Vocab at 0x110ce8290>,
#  u'errors': <gensim.models.keyedvectors.Vocab at 0x1133c0710>,
#  u'whaling': <gensim.models.keyedvectors.Vocab at 0x111f42510>,
#  u'forgetting': <gensim.models.keyedvectors.Vocab at 0x110be0e10>,
#  u'ruthless': <gensim.models.keyedvectors.Vocab at 0x111f42550>,
#  u'thunder': <gensim.models.keyedvectors.Vocab at 0x1091f0ed0>,
#  u'cooking': <gensim.models.keyedvectors.Vocab at 0x1133c0750>,
#  u'contributed': <gensim.models.keyedvectors.Vocab at 0x110ba3990>,
#  u'fingers': <gensim.models.keyedvectors.Vocab at 0x110ba39d0>,
#  u'Until': <gensim.models.keyedvectors.Vocab at 0x1091f0910>,
#  u'Hamilton': <gensim.models.keyedvectors.Vocab at 0x1133c0790>,
#  u'Niagara': <gensim.models.keyedvectors.Vocab at 0x1092a0950>,
#  u'increasing': <gensim.models.keyedvectors.Vocab at 0x111f42590>,
#  u'admiral': <gensim.models.keyedvectors.Vocab at 0x1091f0f10>,
#  u'inducement': <gensim.models.keyedvectors.Vocab at 0x1091f0f50>,
#  u'shure': <gensim.models.keyedvectors.Vocab at 0x1091f0950>,
#  u'_our_': <gensim.models.keyedvectors.Vocab at 0x110cdd750>,
#  u'crouch': <gensim.models.keyedvectors.Vocab at 0x1133c0850>,
#  u'Resina': <gensim.models.keyedvectors.Vocab at 0x1091f0f90>,
#  u'Horeb': <gensim.models.keyedvectors.Vocab at 0x1133c0890>,
#  u'herb': <gensim.models.keyedvectors.Vocab at 0x110ba3b50>,
#  u'fervent': <gensim.models.keyedvectors.Vocab at 0x110bf6910>,
#  u'splinter': <gensim.models.keyedvectors.Vocab at 0x1091fbe50>,
#  u'here': <gensim.models.keyedvectors.Vocab at 0x110ba3bd0>,
#  u'herd': <gensim.models.keyedvectors.Vocab at 0x110ba3c10>,
#  u'47': <gensim.models.keyedvectors.Vocab at 0x109303550>,
#  u'china': <gensim.models.keyedvectors.Vocab at 0x103a41810>,
#  u'Menahem': <gensim.models.keyedvectors.Vocab at 0x109269b10>,
#  u'kissing': <gensim.models.keyedvectors.Vocab at 0x110be0e50>,
#  u'hers': <gensim.models.keyedvectors.Vocab at 0x110ba3c90>,
#  u'shriek': <gensim.models.keyedvectors.Vocab at 0x110ba3cd0>,
#  u'natured': <gensim.models.keyedvectors.Vocab at 0x103a41cd0>,
#  u'kids': <gensim.models.keyedvectors.Vocab at 0x103a41a10>,
#  u'gardeners': <gensim.models.keyedvectors.Vocab at 0x109279fd0>,
#  u'unwillingness': <gensim.models.keyedvectors.Vocab at 0x1091f5050>,
#  u'Dubosc': <gensim.models.keyedvectors.Vocab at 0x103a41b50>,
#  u'pretensions': <gensim.models.keyedvectors.Vocab at 0x110ba3d10>,
#  u'elaborate': <gensim.models.keyedvectors.Vocab at 0x1091f5090>,
#  u'climbed': <gensim.models.keyedvectors.Vocab at 0x103a41a90>,
#  u'Ginger': <gensim.models.keyedvectors.Vocab at 0x111ca2390>,
#  u'controversy': <gensim.models.keyedvectors.Vocab at 0x103a41910>,
#  u'Haman': <gensim.models.keyedvectors.Vocab at 0x111f42650>,
#  u'natures': <gensim.models.keyedvectors.Vocab at 0x103a41b90>,
#  u'NOT': <gensim.models.keyedvectors.Vocab at 0x111f42690>,
#  u'military': <gensim.models.keyedvectors.Vocab at 0x111f426d0>,
#  u'NOW': <gensim.models.keyedvectors.Vocab at 0x111f42710>,
#  u'delicacy': <gensim.models.keyedvectors.Vocab at 0x109308690>,
#  u'Isles': <gensim.models.keyedvectors.Vocab at 0x111ca2610>,
#  u'Goliath': <gensim.models.keyedvectors.Vocab at 0x111f42750>,
#  u'golden': <gensim.models.keyedvectors.Vocab at 0x117644910>,
#  u'whoso': <gensim.models.keyedvectors.Vocab at 0x1092a5610>,
#  u'divide': <gensim.models.keyedvectors.Vocab at 0x111f42790>,
#  u'Heavenly': <gensim.models.keyedvectors.Vocab at 0x1092b6c90>,
#  u'owed': <gensim.models.keyedvectors.Vocab at 0x110ba3dd0>,
#  u'geography': <gensim.models.keyedvectors.Vocab at 0x1091f50d0>,
#  u'Harvey': <gensim.models.keyedvectors.Vocab at 0x117644950>,
#  u'explained': <gensim.models.keyedvectors.Vocab at 0x111f427d0>,
#  u'lengthen': <gensim.models.keyedvectors.Vocab at 0x117644990>,
#  u'Cass': <gensim.models.keyedvectors.Vocab at 0x1092ed990>,
#  u'summons': <gensim.models.keyedvectors.Vocab at 0x111f42850>,
#  u'brought': <gensim.models.keyedvectors.Vocab at 0x110ba3e10>,
#  u'allegory': <gensim.models.keyedvectors.Vocab at 0x110c59590>,
#  u'remnant': <gensim.models.keyedvectors.Vocab at 0x111f42890>,
#  u'stern': <gensim.models.keyedvectors.Vocab at 0x1176449d0>,
#  u'Wales': <gensim.models.keyedvectors.Vocab at 0x110ba3e50>,
#  u'Syrians': <gensim.models.keyedvectors.Vocab at 0x110ba3e90>,
#  u'sunlit': <gensim.models.keyedvectors.Vocab at 0x1091f5150>,
#  u'hoping': <gensim.models.keyedvectors.Vocab at 0x110ba3ed0>,
#  u'Tarlton': <gensim.models.keyedvectors.Vocab at 0x117644a10>,
#  u'Guildensterne': <gensim.models.keyedvectors.Vocab at 0x111f428d0>,
#  u'cheating': <gensim.models.keyedvectors.Vocab at 0x111f42910>,
#  u'frosty': <gensim.models.keyedvectors.Vocab at 0x10922c650>,
#  u'spoke': <gensim.models.keyedvectors.Vocab at 0x111f42950>,
#  u'reproaching': <gensim.models.keyedvectors.Vocab at 0x110c2da10>,
#  u'impartiality': <gensim.models.keyedvectors.Vocab at 0x111f42990>,
#  u'exhort': <gensim.models.keyedvectors.Vocab at 0x110ba3f10>,
#  u'glimmering': <gensim.models.keyedvectors.Vocab at 0x111f429d0>,
#  u'cannibal': <gensim.models.keyedvectors.Vocab at 0x117644a50>,
#  u'borrow': <gensim.models.keyedvectors.Vocab at 0x110bca110>,
#  u'occupying': <gensim.models.keyedvectors.Vocab at 0x110ba3f50>,
#  u'kettles': <gensim.models.keyedvectors.Vocab at 0x111f42a10>,
#  u'music': <gensim.models.keyedvectors.Vocab at 0x117644a90>,
#  u'therefore': <gensim.models.keyedvectors.Vocab at 0x117644ad0>,
#  u'violently': <gensim.models.keyedvectors.Vocab at 0x1092e7510>,
#  u'strike': <gensim.models.keyedvectors.Vocab at 0x1091f51d0>,
#  u'turtledoves': <gensim.models.keyedvectors.Vocab at 0x110ba3fd0>,
#  u'until': <gensim.models.keyedvectors.Vocab at 0x110ba9050>,
#  u'Charity': <gensim.models.keyedvectors.Vocab at 0x110ba9090>,
#  u'expiring': <gensim.models.keyedvectors.Vocab at 0x110ba90d0>,
#  u'females': <gensim.models.keyedvectors.Vocab at 0x1091f5250>,
#  u'harden': <gensim.models.keyedvectors.Vocab at 0x110c53a50>,
#  u'holy': <gensim.models.keyedvectors.Vocab at 0x110ba9110>,
#  u'successful': <gensim.models.keyedvectors.Vocab at 0x111f42a50>,
#  u'43': <gensim.models.keyedvectors.Vocab at 0x109303650>,
#  u'hereby': <gensim.models.keyedvectors.Vocab at 0x1091f5290>,
#  u'whirling': <gensim.models.keyedvectors.Vocab at 0x111f42ad0>,
#  u'Rule': <gensim.models.keyedvectors.Vocab at 0x1091f52d0>,
#  u'hurt': <gensim.models.keyedvectors.Vocab at 0x111f42b10>,
#  u'99': <gensim.models.keyedvectors.Vocab at 0x110ba9190>,
#  u'98': <gensim.models.keyedvectors.Vocab at 0x109206950>,
#  u'harmless': <gensim.models.keyedvectors.Vocab at 0x110cf3a10>,
#  u'inwards': <gensim.models.keyedvectors.Vocab at 0x1091f5310>,
#  u'91': <gensim.models.keyedvectors.Vocab at 0x110ba9250>,
#  u'90': <gensim.models.keyedvectors.Vocab at 0x110ba9290>,
#  u'93': <gensim.models.keyedvectors.Vocab at 0x111fa5ed0>,
#  u'92': <gensim.models.keyedvectors.Vocab at 0x109206a90>,
#  u'95': <gensim.models.keyedvectors.Vocab at 0x110ba9350>,
#  u'contemned': <gensim.models.keyedvectors.Vocab at 0x1092a56d0>,
#  u'97': <gensim.models.keyedvectors.Vocab at 0x110ba93d0>,
#  u'circumstances': <gensim.models.keyedvectors.Vocab at 0x117644b90>,
#  u'locked': <gensim.models.keyedvectors.Vocab at 0x117644bd0>,
#  u'dreadful': <gensim.models.keyedvectors.Vocab at 0x110c2da50>,
#  u'pursue': <gensim.models.keyedvectors.Vocab at 0x1091f5350>,
#  u'famed': <gensim.models.keyedvectors.Vocab at 0x111f42b50>,
#  u'blade': <gensim.models.keyedvectors.Vocab at 0x111f42b90>,
#  u'plunged': <gensim.models.keyedvectors.Vocab at 0x1091f5390>,
#  u'Gogol': <gensim.models.keyedvectors.Vocab at 0x111f42bd0>,
#  u'sweeter': <gensim.models.keyedvectors.Vocab at 0x110ba94d0>,
#  u'leaped': <gensim.models.keyedvectors.Vocab at 0x110ba9510>,
#  u'example': <gensim.models.keyedvectors.Vocab at 0x1091f53d0>,
#  u'transom': <gensim.models.keyedvectors.Vocab at 0x1092e7550>,
#  u'misfortunes': <gensim.models.keyedvectors.Vocab at 0x111f42c10>,
#  u'vanities': <gensim.models.keyedvectors.Vocab at 0x111f42c50>,
#  u'melons': <gensim.models.keyedvectors.Vocab at 0x111f42c90>,
#  u'triple': <gensim.models.keyedvectors.Vocab at 0x110be0f90>,
#  u'wand': <gensim.models.keyedvectors.Vocab at 0x117644c50>,
#  u'La': <gensim.models.keyedvectors.Vocab at 0x117644c90>,
#  u'unjust': <gensim.models.keyedvectors.Vocab at 0x117644cd0>,
#  u'household': <gensim.models.keyedvectors.Vocab at 0x111f42cd0>,
#  u'bitterest': <gensim.models.keyedvectors.Vocab at 0x111f42d10>,
#  u'dragons': <gensim.models.keyedvectors.Vocab at 0x111f42d50>,
#  u'Brian': <gensim.models.keyedvectors.Vocab at 0x10920b510>,
#  u'caution': <gensim.models.keyedvectors.Vocab at 0x1091f5410>,
#  u'want': <gensim.models.keyedvectors.Vocab at 0x117644d10>,
#  u'perverseness': <gensim.models.keyedvectors.Vocab at 0x110c9bbd0>,
#  u'cruising': <gensim.models.keyedvectors.Vocab at 0x110c5e1d0>,
#  u'seekest': <gensim.models.keyedvectors.Vocab at 0x109324250>,
#  u'reprove': <gensim.models.keyedvectors.Vocab at 0x111f42dd0>,
#  u'absolute': <gensim.models.keyedvectors.Vocab at 0x117644d50>,
#  u'Eagle': <gensim.models.keyedvectors.Vocab at 0x111f42e10>,
#  u'ungodly': <gensim.models.keyedvectors.Vocab at 0x1092e21d0>,
#  u'knows': <gensim.models.keyedvectors.Vocab at 0x109334b90>,
#  u'groaned': <gensim.models.keyedvectors.Vocab at 0x111cad810>,
#  u'travel': <gensim.models.keyedvectors.Vocab at 0x117644d90>,
#  u'damage': <gensim.models.keyedvectors.Vocab at 0x111f42e50>,
#  u'machine': <gensim.models.keyedvectors.Vocab at 0x111f42e90>,
#  u'squeeze': <gensim.models.keyedvectors.Vocab at 0x110ba3150>,
#  u'hot': <gensim.models.keyedvectors.Vocab at 0x110ba9650>,
#  u'hesitatingly': <gensim.models.keyedvectors.Vocab at 0x1091f5490>,
#  u'hop': <gensim.models.keyedvectors.Vocab at 0x110ba9690>,
#  u'significance': <gensim.models.keyedvectors.Vocab at 0x110ba96d0>,
#  u'main': <gensim.models.keyedvectors.Vocab at 0x110c7a710>,
#  u'tangled': <gensim.models.keyedvectors.Vocab at 0x1091f54d0>,
#  u'chase': <gensim.models.keyedvectors.Vocab at 0x110be5050>,
#  u'cadence': <gensim.models.keyedvectors.Vocab at 0x117644dd0>,
#  u'retreating': <gensim.models.keyedvectors.Vocab at 0x110cdd850>,
#  u'A': <gensim.models.keyedvectors.Vocab at 0x110ba9710>,
#  u'abstraction': <gensim.models.keyedvectors.Vocab at 0x1091f5550>,
#  u'Bates': <gensim.models.keyedvectors.Vocab at 0x117644e50>,
#  u'beauty': <gensim.models.keyedvectors.Vocab at 0x110ba9750>,
#  u'peece': <gensim.models.keyedvectors.Vocab at 0x117644e90>,
#  u'swing': <gensim.models.keyedvectors.Vocab at 0x109324310>,
#  u'Charming': <gensim.models.keyedvectors.Vocab at 0x110c1c050>,
#  u'shores': <gensim.models.keyedvectors.Vocab at 0x109211290>,
#  u'Players': <gensim.models.keyedvectors.Vocab at 0x111edf350>,
#  u'wrong': <gensim.models.keyedvectors.Vocab at 0x117644ed0>,
#  u'Gittite': <gensim.models.keyedvectors.Vocab at 0x110be50d0>,
#  u'destined': <gensim.models.keyedvectors.Vocab at 0x111f42f10>,
#  u'twined': <gensim.models.keyedvectors.Vocab at 0x117644f10>,
#  u'Aloud': <gensim.models.keyedvectors.Vocab at 0x111cb3410>,
#  u'vase': <gensim.models.keyedvectors.Vocab at 0x1092a5750>,
#  u'types': <gensim.models.keyedvectors.Vocab at 0x1091f55d0>,
#  u'keepe': <gensim.models.keyedvectors.Vocab at 0x111f42f50>,
#  u'profess': <gensim.models.keyedvectors.Vocab at 0x109269c10>,
#  u'calves': <gensim.models.keyedvectors.Vocab at 0x111f42f90>,
#  u'scourge': <gensim.models.keyedvectors.Vocab at 0x111f42fd0>,
#  u'notable': <gensim.models.keyedvectors.Vocab at 0x110c85e90>,
#  u'endeavoured': <gensim.models.keyedvectors.Vocab at 0x110ba9790>,
#  u'youths': <gensim.models.keyedvectors.Vocab at 0x110ba97d0>,
#  u'sensitive': <gensim.models.keyedvectors.Vocab at 0x110c38f90>,
#  u'revolt': <gensim.models.keyedvectors.Vocab at 0x110ba9810>,
#  u'presiding': <gensim.models.keyedvectors.Vocab at 0x110ba9850>,
#  u'sickening': <gensim.models.keyedvectors.Vocab at 0x117644f50>,
#  u'tulip': <gensim.models.keyedvectors.Vocab at 0x117644f90>,
#  u'Mabel': <gensim.models.keyedvectors.Vocab at 0x117644fd0>,
#  u'keeps': <gensim.models.keyedvectors.Vocab at 0x111f480d0>,
#  u'democratic': <gensim.models.keyedvectors.Vocab at 0x109211c10>,
#  u'mightier': <gensim.models.keyedvectors.Vocab at 0x110ca0d90>,
#  u'wing': <gensim.models.keyedvectors.Vocab at 0x111f48110>,
#  u'wind': <gensim.models.keyedvectors.Vocab at 0x111f48150>,
#  u'wine': <gensim.models.keyedvectors.Vocab at 0x111f48190>,
#  u'blind': <gensim.models.keyedvectors.Vocab at 0x111e0bbd0>,
#  u'Cyrene': <gensim.models.keyedvectors.Vocab at 0x110c5e210>,
#  u'welcomed': <gensim.models.keyedvectors.Vocab at 0x111c97090>,
#  u'Eliashib': <gensim.models.keyedvectors.Vocab at 0x111c970d0>,
#  u'concurrence': <gensim.models.keyedvectors.Vocab at 0x111c97110>,
#  u'govern': <gensim.models.keyedvectors.Vocab at 0x1092a5790>,
#  u'Giant': <gensim.models.keyedvectors.Vocab at 0x110cdd950>,
#  u'subiect': <gensim.models.keyedvectors.Vocab at 0x1091f5690>,
#  u'profaned': <gensim.models.keyedvectors.Vocab at 0x111f481d0>,
#  u'suspend': <gensim.models.keyedvectors.Vocab at 0x110cdd990>,
#  u'sunshine': <gensim.models.keyedvectors.Vocab at 0x109145d10>,
#  u'ewe': <gensim.models.keyedvectors.Vocab at 0x110c9bc90>,
#  u'forbad': <gensim.models.keyedvectors.Vocab at 0x110cd2ad0>,
#  u'enquiring': <gensim.models.keyedvectors.Vocab at 0x1091f56d0>,
#  u'fetched': <gensim.models.keyedvectors.Vocab at 0x110cdd9d0>,
#  u'rewarded': <gensim.models.keyedvectors.Vocab at 0x111c97190>,
#  u'hook': <gensim.models.keyedvectors.Vocab at 0x1091408d0>,
#  u'wrought': <gensim.models.keyedvectors.Vocab at 0x1091f5750>,
#  u'playhouse': <gensim.models.keyedvectors.Vocab at 0x111c971d0>,
#  u'fir': <gensim.models.keyedvectors.Vocab at 0x111c97210>,
#  u'His': <gensim.models.keyedvectors.Vocab at 0x111c97250>,
#  u'wickedly': <gensim.models.keyedvectors.Vocab at 0x111c97290>,
#  u'fit': <gensim.models.keyedvectors.Vocab at 0x111c972d0>,
#  u'screaming': <gensim.models.keyedvectors.Vocab at 0x111c97310>,
#  u'fix': <gensim.models.keyedvectors.Vocab at 0x111c97350>,
#  u'occupations': <gensim.models.keyedvectors.Vocab at 0x110c22490>,
#  u'Kadesh': <gensim.models.keyedvectors.Vocab at 0x110c434d0>,
#  u'Zarhites': <gensim.models.keyedvectors.Vocab at 0x1091f57d0>,
#  u'Montague': <gensim.models.keyedvectors.Vocab at 0x111c973d0>,
#  u'Harris': <gensim.models.keyedvectors.Vocab at 0x111f48250>,
#  u'fig': <gensim.models.keyedvectors.Vocab at 0x111c97410>,
#  u'ringstraked': <gensim.models.keyedvectors.Vocab at 0x110bfb5d0>,
#  u'fie': <gensim.models.keyedvectors.Vocab at 0x111c97450>,
#  u'nobler': <gensim.models.keyedvectors.Vocab at 0x110ba9a90>,
#  u'Know': <gensim.models.keyedvectors.Vocab at 0x109303710>,
#  u'hidden': <gensim.models.keyedvectors.Vocab at 0x111f48290>,
#  u'fin': <gensim.models.keyedvectors.Vocab at 0x111c97490>,
#  u'Him': <gensim.models.keyedvectors.Vocab at 0x111c974d0>,
#  u'Hin': <gensim.models.keyedvectors.Vocab at 0x111c97510>,
#  u'Lest': <gensim.models.keyedvectors.Vocab at 0x1091f0b50>,
#  u'glorify': <gensim.models.keyedvectors.Vocab at 0x111f482d0>,
#  u'grievous': <gensim.models.keyedvectors.Vocab at 0x110ba9b90>,
#  u'copying': <gensim.models.keyedvectors.Vocab at 0x1091778d0>,
#  u'Hickory': <gensim.models.keyedvectors.Vocab at 0x111c97590>,
#  u'enrich': <gensim.models.keyedvectors.Vocab at 0x111f48310>,
#  u'slate': <gensim.models.keyedvectors.Vocab at 0x1091f5910>,
#  u'Zichri': <gensim.models.keyedvectors.Vocab at 0x1091f5950>,
#  u'Seth': <gensim.models.keyedvectors.Vocab at 0x110ba9bd0>,
#  u'disturb': <gensim.models.keyedvectors.Vocab at 0x1091f0b90>,
#  u'MRS': <gensim.models.keyedvectors.Vocab at 0x109216b10>,
#  u'throned': <gensim.models.keyedvectors.Vocab at 0x1091f5990>,
#  u'raiseth': <gensim.models.keyedvectors.Vocab at 0x111c975d0>,
#  u'effects': <gensim.models.keyedvectors.Vocab at 0x111c97610>,
#  u'schools': <gensim.models.keyedvectors.Vocab at 0x111cb8d90>,
#  u'beaux': <gensim.models.keyedvectors.Vocab at 0x110ba9c10>,
#  u'sixteen': <gensim.models.keyedvectors.Vocab at 0x111c97650>,
#  u'silver': <gensim.models.keyedvectors.Vocab at 0x111f48350>,
#  u'scholar': <gensim.models.keyedvectors.Vocab at 0x110ba3790>,
#  u'rumour': <gensim.models.keyedvectors.Vocab at 0x111f48390>,
#  u'clumsy': <gensim.models.keyedvectors.Vocab at 0x110ba9c50>,
#  u'strayed': <gensim.models.keyedvectors.Vocab at 0x110ba9c90>,
#  u'Sepharvaim': <gensim.models.keyedvectors.Vocab at 0x109324410>,
#  u'successfully': <gensim.models.keyedvectors.Vocab at 0x109313f10>,
#  u'Shame': <gensim.models.keyedvectors.Vocab at 0x111c97690>,
#  u'mob': <gensim.models.keyedvectors.Vocab at 0x110c85b10>,
#  u'arrow': <gensim.models.keyedvectors.Vocab at 0x111c976d0>,
#  u'poisonous': <gensim.models.keyedvectors.Vocab at 0x10930ea10>,
#  u'lightness': <gensim.models.keyedvectors.Vocab at 0x110c9b750>,
#  u'Mouse': <gensim.models.keyedvectors.Vocab at 0x111cbe4d0>,
#  u'moving': <gensim.models.keyedvectors.Vocab at 0x110cfeb90>,
#  u'blushed': <gensim.models.keyedvectors.Vocab at 0x110ba9d10>,
#  u'Borne': <gensim.models.keyedvectors.Vocab at 0x111cbe6d0>,
#  u'burial': <gensim.models.keyedvectors.Vocab at 0x111c97710>,
#  u'preceded': <gensim.models.keyedvectors.Vocab at 0x111f48450>,
#  u'Curse': <gensim.models.keyedvectors.Vocab at 0x10921c390>,
#  u'telescope': <gensim.models.keyedvectors.Vocab at 0x111c97750>,
#  u'woes': <gensim.models.keyedvectors.Vocab at 0x111f484d0>,
#  u'concord': <gensim.models.keyedvectors.Vocab at 0x110ba9dd0>,
#  u'garment': <gensim.models.keyedvectors.Vocab at 0x111f48510>,
#  u'Eliza': <gensim.models.keyedvectors.Vocab at 0x110ba9e10>,
#  u'stronger': <gensim.models.keyedvectors.Vocab at 0x110bf6950>,
#  u'bowls': <gensim.models.keyedvectors.Vocab at 0x111f48550>,
#  u'contracting': <gensim.models.keyedvectors.Vocab at 0x110ba9e50>,
#  u'precedes': <gensim.models.keyedvectors.Vocab at 0x111f48590>,
#  u'fortnight': <gensim.models.keyedvectors.Vocab at 0x111f485d0>,
#  u'impossible': <gensim.models.keyedvectors.Vocab at 0x111fbbf10>,
#  u'cathedral': <gensim.models.keyedvectors.Vocab at 0x110ba9e90>,
#  u'whit': <gensim.models.keyedvectors.Vocab at 0x110ba9ed0>,
#  u'blinded': <gensim.models.keyedvectors.Vocab at 0x111f48610>,
#  u'whip': <gensim.models.keyedvectors.Vocab at 0x10921cb10>,
#  u'borne': <gensim.models.keyedvectors.Vocab at 0x110ba9f10>,
#  u'misfortune': <gensim.models.keyedvectors.Vocab at 0x110ba9f50>,
#  u'ha': <gensim.models.keyedvectors.Vocab at 0x111e78b50>,
#  u'excepting': <gensim.models.keyedvectors.Vocab at 0x110ba9f90>,
#  u'persisted': <gensim.models.keyedvectors.Vocab at 0x1091f0c90>,
#  u'weeping': <gensim.models.keyedvectors.Vocab at 0x110d09710>,
#  u'mason': <gensim.models.keyedvectors.Vocab at 0x111c977d0>,
#  u're': <gensim.models.keyedvectors.Vocab at 0x1091f5ad0>,
#  u'encourage': <gensim.models.keyedvectors.Vocab at 0x111c97810>,
#  u'groans': <gensim.models.keyedvectors.Vocab at 0x110cb6a50>,
#  u'Rabbit': <gensim.models.keyedvectors.Vocab at 0x110ba9fd0>,
#  u'millions': <gensim.models.keyedvectors.Vocab at 0x1091b3cd0>,
#  u'Vanity': <gensim.models.keyedvectors.Vocab at 0x110bae050>,
#  u'Josiah': <gensim.models.keyedvectors.Vocab at 0x1091f5b50>,
#  u'foundation': <gensim.models.keyedvectors.Vocab at 0x1091f5b90>,
#  u'stamping': <gensim.models.keyedvectors.Vocab at 0x111c97890>,
#  u'Word': <gensim.models.keyedvectors.Vocab at 0x1091f5bd0>,
#  u'Reynol': <gensim.models.keyedvectors.Vocab at 0x111c978d0>,
#  u'assured': <gensim.models.keyedvectors.Vocab at 0x111f48650>,
#  u'leopard': <gensim.models.keyedvectors.Vocab at 0x110c9bd50>,
#  u'wavered': <gensim.models.keyedvectors.Vocab at 0x1091f0cd0>,
#  u'threatened': <gensim.models.keyedvectors.Vocab at 0x1091f5c90>,
#  u'strata': <gensim.models.keyedvectors.Vocab at 0x111c97910>,
#  u'_her_': <gensim.models.keyedvectors.Vocab at 0x111f486d0>,
#  u'yesterday': <gensim.models.keyedvectors.Vocab at 0x110c9bd90>,
#  u'faculties': <gensim.models.keyedvectors.Vocab at 0x1091f5d10>,
#  u'grapes': <gensim.models.keyedvectors.Vocab at 0x110bae110>,
#  u'element': <gensim.models.keyedvectors.Vocab at 0x110bae150>,
#  u'crowned': <gensim.models.keyedvectors.Vocab at 0x1091f5d50>,
#  u'estimate': <gensim.models.keyedvectors.Vocab at 0x111c97950>,
#  u'contrition': <gensim.models.keyedvectors.Vocab at 0x10922cbd0>,
#  u'laburnum': <gensim.models.keyedvectors.Vocab at 0x111c97990>,
#  u'universally': <gensim.models.keyedvectors.Vocab at 0x111c979d0>,
#  u'Hora': <gensim.models.keyedvectors.Vocab at 0x111f48790>,
#  u'husbands': <gensim.models.keyedvectors.Vocab at 0x110d095d0>,
#  u'enormous': <gensim.models.keyedvectors.Vocab at 0x1091f5d90>,
#  u'ate': <gensim.models.keyedvectors.Vocab at 0x110bae210>,
#  u'district': <gensim.models.keyedvectors.Vocab at 0x111f48810>,
#  u'shelves': <gensim.models.keyedvectors.Vocab at 0x110bae250>,
#  u'selfe': <gensim.models.keyedvectors.Vocab at 0x111c97a10>,
#  u'flurry': <gensim.models.keyedvectors.Vocab at 0x110c9be10>,
#  u'graces': <gensim.models.keyedvectors.Vocab at 0x1092a5950>,
#  u'eares': <gensim.models.keyedvectors.Vocab at 0x1091f5dd0>,
#  u'shipped': <gensim.models.keyedvectors.Vocab at 0x1091f5e10>,
#  u'disturbed': <gensim.models.keyedvectors.Vocab at 0x111c97a50>,
#  u'speedy': <gensim.models.keyedvectors.Vocab at 0x1091f5e50>,
#  u'Human': <gensim.models.keyedvectors.Vocab at 0x111f48850>,
#  u'reserving': <gensim.models.keyedvectors.Vocab at 0x1091f5ed0>,
#  u'Amaziah': <gensim.models.keyedvectors.Vocab at 0x10922cc10>,
#  u'clothes': <gensim.models.keyedvectors.Vocab at 0x111e7d350>,
#  u'speeds': <gensim.models.keyedvectors.Vocab at 0x1091f5f10>,
#  u'purpose': <gensim.models.keyedvectors.Vocab at 0x1092e77d0>,
#  u'Levites': <gensim.models.keyedvectors.Vocab at 0x111c97a90>,
#  u'lightened': <gensim.models.keyedvectors.Vocab at 0x111e41110>,
#  u'impression': <gensim.models.keyedvectors.Vocab at 0x110c4ef50>,
#  u'foreskins': <gensim.models.keyedvectors.Vocab at 0x110c5e310>,
#  u'playfully': <gensim.models.keyedvectors.Vocab at 0x110bae390>,
#  u'Please': <gensim.models.keyedvectors.Vocab at 0x111f488d0>,
#  u'wast': <gensim.models.keyedvectors.Vocab at 0x111f48910>,
#  u'channels': <gensim.models.keyedvectors.Vocab at 0x1091f5f50>,
#  u'Chants': <gensim.models.keyedvectors.Vocab at 0x111c97b10>,
#  u'instruct': <gensim.models.keyedvectors.Vocab at 0x111f48990>,
#  u'Merlin': <gensim.models.keyedvectors.Vocab at 0x111e26050>,
#  u'clamorous': <gensim.models.keyedvectors.Vocab at 0x111c97b50>,
#  u'wasn': <gensim.models.keyedvectors.Vocab at 0x111f489d0>,
#  u'sallied': <gensim.models.keyedvectors.Vocab at 0x1091fb050>,
#  u'curing': <gensim.models.keyedvectors.Vocab at 0x10931ea90>,
#  u'specially': <gensim.models.keyedvectors.Vocab at 0x1091f0d90>,
#  u'bitten': <gensim.models.keyedvectors.Vocab at 0x110bae410>,
#  u'Exeunt': <gensim.models.keyedvectors.Vocab at 0x111c97b90>,
#  u'service': <gensim.models.keyedvectors.Vocab at 0x111c97bd0>,
#  u'Fearless': <gensim.models.keyedvectors.Vocab at 0x111c97c10>,
#  u'engagement': <gensim.models.keyedvectors.Vocab at 0x111f48a10>,
#  u'needed': <gensim.models.keyedvectors.Vocab at 0x111c97c50>,
#  u'perturbations': <gensim.models.keyedvectors.Vocab at 0x111cc9c90>,
#  u'master': <gensim.models.keyedvectors.Vocab at 0x111c97c90>,
#  u'blossoms': <gensim.models.keyedvectors.Vocab at 0x111f48a50>,
#  u'chaises': <gensim.models.keyedvectors.Vocab at 0x111fabc10>,
#  u'manger': <gensim.models.keyedvectors.Vocab at 0x110be0510>,
#  u'architect': <gensim.models.keyedvectors.Vocab at 0x10933af10>,
#  u'legs': <gensim.models.keyedvectors.Vocab at 0x111f48ad0>,
#  u'bitter': <gensim.models.keyedvectors.Vocab at 0x110bae450>,
#  u'ranging': <gensim.models.keyedvectors.Vocab at 0x110bae490>,
#  u'listen': <gensim.models.keyedvectors.Vocab at 0x111f48b10>,
#  u'rewards': <gensim.models.keyedvectors.Vocab at 0x111c97cd0>,
#  u'collapse': <gensim.models.keyedvectors.Vocab at 0x111f48b50>,
#  u'cushions': <gensim.models.keyedvectors.Vocab at 0x110bae510>,
#  u'stake': <gensim.models.keyedvectors.Vocab at 0x110c17710>,
#  u'wisdom': <gensim.models.keyedvectors.Vocab at 0x111f48b90>,
#  u'motionless': <gensim.models.keyedvectors.Vocab at 0x1092e7890>,
#  u'Victory': <gensim.models.keyedvectors.Vocab at 0x110bae550>,
#  u'palsy': <gensim.models.keyedvectors.Vocab at 0x110bae590>,
#  u'crawl': <gensim.models.keyedvectors.Vocab at 0x1091fb0d0>,
#  u'lunged': <gensim.models.keyedvectors.Vocab at 0x1091fb110>,
#  u'positively': <gensim.models.keyedvectors.Vocab at 0x111c97d10>,
#  u').--': <gensim.models.keyedvectors.Vocab at 0x110bae5d0>,
#  u'Beautiful': <gensim.models.keyedvectors.Vocab at 0x111f48bd0>,
#  u'Meshach': <gensim.models.keyedvectors.Vocab at 0x110bae610>,
#  u'peril': <gensim.models.keyedvectors.Vocab at 0x110bae650>,
#  u'exultation': <gensim.models.keyedvectors.Vocab at 0x1091fb150>,
#  u'showed': <gensim.models.keyedvectors.Vocab at 0x1091fb190>,
#  u'Matthew': <gensim.models.keyedvectors.Vocab at 0x1091fb1d0>,
#  u'outlaw': <gensim.models.keyedvectors.Vocab at 0x111f48c10>,
#  u'tree': <gensim.models.keyedvectors.Vocab at 0x1091fb210>,
#  u'idly': <gensim.models.keyedvectors.Vocab at 0x111c97d50>,
#  u'blasphemer': <gensim.models.keyedvectors.Vocab at 0x1091fb250>,
#  u'project': <gensim.models.keyedvectors.Vocab at 0x111cce910>,
#  u'pioneer': <gensim.models.keyedvectors.Vocab at 0x1092d1110>,
#  u'idle': <gensim.models.keyedvectors.Vocab at 0x111c97d90>,
#  u'exclaimed': <gensim.models.keyedvectors.Vocab at 0x111c97dd0>,
#  u'Seraph': <gensim.models.keyedvectors.Vocab at 0x111c97e10>,
#  u'profitable': <gensim.models.keyedvectors.Vocab at 0x110b88550>,
#  u'spermaceti': <gensim.models.keyedvectors.Vocab at 0x111ccea10>,
#  u'103': <gensim.models.keyedvectors.Vocab at 0x1092a5b90>,
#  u'feeling': <gensim.models.keyedvectors.Vocab at 0x111c97e50>,
#  u'acquisition': <gensim.models.keyedvectors.Vocab at 0x110bae6d0>,
#  u'Sherebiah': <gensim.models.keyedvectors.Vocab at 0x110c0cad0>,
#  u'seduced': <gensim.models.keyedvectors.Vocab at 0x1093246d0>,
#  u'Angell': <gensim.models.keyedvectors.Vocab at 0x10922c5d0>,
#  u'groaning': <gensim.models.keyedvectors.Vocab at 0x111f48d10>,
#  u'willingness': <gensim.models.keyedvectors.Vocab at 0x1091fb350>,
#  u'Chicago': <gensim.models.keyedvectors.Vocab at 0x111c97e90>,
#  u'believest': <gensim.models.keyedvectors.Vocab at 0x110bae710>,
#  u'wealth': <gensim.models.keyedvectors.Vocab at 0x1092c1490>,
#  u'Abishua': <gensim.models.keyedvectors.Vocab at 0x110bae790>,
#  u'craven': <gensim.models.keyedvectors.Vocab at 0x1092e78d0>,
#  u'headland': <gensim.models.keyedvectors.Vocab at 0x110bae7d0>,
#  u'humouredly': <gensim.models.keyedvectors.Vocab at 0x111f48d50>,
#  u'brawny': <gensim.models.keyedvectors.Vocab at 0x111c97ed0>,
#  u'Son': <gensim.models.keyedvectors.Vocab at 0x10922cd10>,
#  u'Angels': <gensim.models.keyedvectors.Vocab at 0x111f48d90>,
#  u'Williams': <gensim.models.keyedvectors.Vocab at 0x111f48dd0>,
#  u'dozen': <gensim.models.keyedvectors.Vocab at 0x111c97f50>,
#  u'doore': <gensim.models.keyedvectors.Vocab at 0x1091fb3d0>,
#  u'affairs': <gensim.models.keyedvectors.Vocab at 0x111c97f90>,
#  u'Them': <gensim.models.keyedvectors.Vocab at 0x111c97fd0>,
#  u'Thel': <gensim.models.keyedvectors.Vocab at 0x111c9d050>,
#  u'wholesome': <gensim.models.keyedvectors.Vocab at 0x111c9d090>,
#  u'mostly': <gensim.models.keyedvectors.Vocab at 0x111e41210>,
#  u'regretting': <gensim.models.keyedvectors.Vocab at 0x111f7fe10>,
#  u'mill': <gensim.models.keyedvectors.Vocab at 0x110c741d0>,
#  u'Thee': <gensim.models.keyedvectors.Vocab at 0x111c9d110>,
#  u'uncouth': <gensim.models.keyedvectors.Vocab at 0x111c9d150>,
#  u'gripe': <gensim.models.keyedvectors.Vocab at 0x1091fb490>,
#  u'haste': <gensim.models.keyedvectors.Vocab at 0x10924dcd0>,
#  u'eagerly': <gensim.models.keyedvectors.Vocab at 0x111f48e90>,
#  u'lavers': <gensim.models.keyedvectors.Vocab at 0x110c5e3d0>,
#  u'NANTUCKET': <gensim.models.keyedvectors.Vocab at 0x111f48ed0>,
#  u'causing': <gensim.models.keyedvectors.Vocab at 0x111f48f10>,
#  u'absorbed': <gensim.models.keyedvectors.Vocab at 0x110bae810>,
#  u'amusing': <gensim.models.keyedvectors.Vocab at 0x1091fb510>,
#  u'They': <gensim.models.keyedvectors.Vocab at 0x111c9d190>,
#  u'hum': <gensim.models.keyedvectors.Vocab at 0x1091b3ed0>,
#  u'Ask': <gensim.models.keyedvectors.Vocab at 0x1091fb5d0>,
#  u'Frode': <gensim.models.keyedvectors.Vocab at 0x111f48f50>,
#  u'Bani': <gensim.models.keyedvectors.Vocab at 0x111f48f90>,
#  u'Bank': <gensim.models.keyedvectors.Vocab at 0x10922cfd0>,
#  u'imprudent': <gensim.models.keyedvectors.Vocab at 0x1091fb610>,
#  u'Jones': <gensim.models.keyedvectors.Vocab at 0x1091fb650>,
#  u'Seir': <gensim.models.keyedvectors.Vocab at 0x111c9d1d0>,
#  u'Messiah': <gensim.models.keyedvectors.Vocab at 0x110c4e250>,
#  u'Wise': <gensim.models.keyedvectors.Vocab at 0x111f48fd0>,
#  u'Gabriel': <gensim.models.keyedvectors.Vocab at 0x110bae890>,
#  u'shall': <gensim.models.keyedvectors.Vocab at 0x110bae8d0>,
#  u'Jotham': <gensim.models.keyedvectors.Vocab at 0x111c9d210>,
#  u'limitless': <gensim.models.keyedvectors.Vocab at 0x111c9d250>,
#  u'wells': <gensim.models.keyedvectors.Vocab at 0x1091fb690>,
#  u'toil': <gensim.models.keyedvectors.Vocab at 0x1092e7910>,
#  u'mouth': <gensim.models.keyedvectors.Vocab at 0x111c9d290>,
#  u'reverence': <gensim.models.keyedvectors.Vocab at 0x111c9d2d0>,
#  u'drought': <gensim.models.keyedvectors.Vocab at 0x111f4d090>,
#  u'morality': <gensim.models.keyedvectors.Vocab at 0x111f4d0d0>,
#  u'expound': <gensim.models.keyedvectors.Vocab at 0x111c9d350>,
#  u'singer': <gensim.models.keyedvectors.Vocab at 0x111c9d390>,
#  u'chemistry': <gensim.models.keyedvectors.Vocab at 0x109177b90>,
#  u'released': <gensim.models.keyedvectors.Vocab at 0x109324750>,
#  u'grove': <gensim.models.keyedvectors.Vocab at 0x111f4d110>,
#  u'professor': <gensim.models.keyedvectors.Vocab at 0x111f4d150>,
#  u'Kingston': <gensim.models.keyedvectors.Vocab at 0x111f4d190>,
#  u'desirous': <gensim.models.keyedvectors.Vocab at 0x111e7d490>,
#  u'singed': <gensim.models.keyedvectors.Vocab at 0x111c9d3d0>,
#  u'fugitives': <gensim.models.keyedvectors.Vocab at 0x111c9d410>,
#  u'Mansion': <gensim.models.keyedvectors.Vocab at 0x110baea10>,
#  u'nineteenth': <gensim.models.keyedvectors.Vocab at 0x110baea50>,
#  u'How': <gensim.models.keyedvectors.Vocab at 0x110bcfd50>,
#  u'scream': <gensim.models.keyedvectors.Vocab at 0x111c9d450>,
#  u'came': <gensim.models.keyedvectors.Vocab at 0x1091fb710>,
#  u'marvel': <gensim.models.keyedvectors.Vocab at 0x110baead0>,
#  u'saying': <gensim.models.keyedvectors.Vocab at 0x111c9d490>,
#  u'bomb': <gensim.models.keyedvectors.Vocab at 0x111f4d210>,
#  u'departing': <gensim.models.keyedvectors.Vocab at 0x111f4d250>,
#  u'insects': <gensim.models.keyedvectors.Vocab at 0x1091fb790>,
#  u'meetings': <gensim.models.keyedvectors.Vocab at 0x1091fb7d0>,
#  u'tempter': <gensim.models.keyedvectors.Vocab at 0x111c9d4d0>,
#  u'liest': <gensim.models.keyedvectors.Vocab at 0x110baeb50>,
#  u'padded': <gensim.models.keyedvectors.Vocab at 0x111c9d510>,
#  u'regiments': <gensim.models.keyedvectors.Vocab at 0x110c06bd0>,
#  u'Paradise': <gensim.models.keyedvectors.Vocab at 0x110baeb90>,
#  u'thinketh': <gensim.models.keyedvectors.Vocab at 0x1091fb850>,
#  u'tempted': <gensim.models.keyedvectors.Vocab at 0x111c9d550>,
#  u'driving': <gensim.models.keyedvectors.Vocab at 0x110cc7390>,
#  u'abreast': <gensim.models.keyedvectors.Vocab at 0x1091fb890>,
#  u'Gomorrah': <gensim.models.keyedvectors.Vocab at 0x1092e7990>,
#  u'lessons': <gensim.models.keyedvectors.Vocab at 0x1091fb8d0>,
#  u'apace': <gensim.models.keyedvectors.Vocab at 0x111c9d5d0>,
#  u'touches': <gensim.models.keyedvectors.Vocab at 0x110baec50>,
#  u'copy': <gensim.models.keyedvectors.Vocab at 0x109324810>,
#  u'shuffling': <gensim.models.keyedvectors.Vocab at 0x111f4d2d0>,
#  u'quaint': <gensim.models.keyedvectors.Vocab at 0x1091fb910>,
#  u'cousins': <gensim.models.keyedvectors.Vocab at 0x111f4d310>,
#  u'105': <gensim.models.keyedvectors.Vocab at 0x1092a5d10>,
#  u'mens': <gensim.models.keyedvectors.Vocab at 0x111f4d350>,
#  u'extasie': <gensim.models.keyedvectors.Vocab at 0x1091fb950>,
#  u'theme': <gensim.models.keyedvectors.Vocab at 0x111f4d390>,
#  u'Peradventure': <gensim.models.keyedvectors.Vocab at 0x110baed10>,
#  u'bliss': <gensim.models.keyedvectors.Vocab at 0x111cd9d50>,
#  u'touched': <gensim.models.keyedvectors.Vocab at 0x110baed50>,
#  u'rich': <gensim.models.keyedvectors.Vocab at 0x111c9d610>,
#  u'mend': <gensim.models.keyedvectors.Vocab at 0x111f4d3d0>,
#  u'rice': <gensim.models.keyedvectors.Vocab at 0x111c9d650>,
#  u'plate': <gensim.models.keyedvectors.Vocab at 0x111c9d690>,
#  u'remotest': <gensim.models.keyedvectors.Vocab at 0x111c9d6d0>,
#  u'strip': <gensim.models.keyedvectors.Vocab at 0x110cabb10>,
#  u'Churchills': <gensim.models.keyedvectors.Vocab at 0x110baedd0>,
#  u'Nevertheless': <gensim.models.keyedvectors.Vocab at 0x111cdf0d0>,
#  u'stammered': <gensim.models.keyedvectors.Vocab at 0x110baee10>,
#  u'denounce': <gensim.models.keyedvectors.Vocab at 0x1091fb9d0>,
#  u'terrors': <gensim.models.keyedvectors.Vocab at 0x1091fba10>,
#  u'foremost': <gensim.models.keyedvectors.Vocab at 0x1091fba50>,
#  u'pocket': <gensim.models.keyedvectors.Vocab at 0x1091fba90>,
#  u'anxious': <gensim.models.keyedvectors.Vocab at 0x110c3d890>,
#  u'altogether': <gensim.models.keyedvectors.Vocab at 0x111c9d750>,
#  u'X': <gensim.models.keyedvectors.Vocab at 0x110baee50>,
#  u'givest': <gensim.models.keyedvectors.Vocab at 0x111c9d7d0>,
#  u'relish': <gensim.models.keyedvectors.Vocab at 0x1091fbad0>,
#  u'Colorado': <gensim.models.keyedvectors.Vocab at 0x110baee90>,
#  u'Senators': <gensim.models.keyedvectors.Vocab at 0x111c9d810>,
#  u'avenger': <gensim.models.keyedvectors.Vocab at 0x111f4d450>,
#  u'nicely': <gensim.models.keyedvectors.Vocab at 0x111c9d850>,
#  u'ever': <gensim.models.keyedvectors.Vocab at 0x110c5e590>,
#  u'boarder': <gensim.models.keyedvectors.Vocab at 0x111c9d890>,
#  u'Prayers': <gensim.models.keyedvectors.Vocab at 0x109269ed0>,
#  u'dipping': <gensim.models.keyedvectors.Vocab at 0x1091fbb10>,
#  u'patch': <gensim.models.keyedvectors.Vocab at 0x111c9d8d0>,
#  u'Rio': <gensim.models.keyedvectors.Vocab at 0x111c9d910>,
#  u'eyelids': <gensim.models.keyedvectors.Vocab at 0x111c9d950>,
#  u'avenged': <gensim.models.keyedvectors.Vocab at 0x111f4d490>,
#  u'XVII': <gensim.models.keyedvectors.Vocab at 0x111cdfa10>,
#  u'harbors': <gensim.models.keyedvectors.Vocab at 0x111f4d4d0>,
#  u'flanked': <gensim.models.keyedvectors.Vocab at 0x111f4d510>,
#  u'eventually': <gensim.models.keyedvectors.Vocab at 0x110c06a10>,
#  u'release': <gensim.models.keyedvectors.Vocab at 0x110baef10>,
#  u'Rig': <gensim.models.keyedvectors.Vocab at 0x111c9d990>,
#  u'Rid': <gensim.models.keyedvectors.Vocab at 0x111c9d9d0>,
#  u'hasten': <gensim.models.keyedvectors.Vocab at 0x1091fbc90>,
#  u'boarded': <gensim.models.keyedvectors.Vocab at 0x111c9da10>,
#  u'circling': <gensim.models.keyedvectors.Vocab at 0x1092e7a50>,
#  u'respond': <gensim.models.keyedvectors.Vocab at 0x10923d190>,
#  u'blew': <gensim.models.keyedvectors.Vocab at 0x111f4d550>,
#  u'creepeth': <gensim.models.keyedvectors.Vocab at 0x110cc1350>,
#  u'disaster': <gensim.models.keyedvectors.Vocab at 0x111f4d590>,
#  u'fair': <gensim.models.keyedvectors.Vocab at 0x111f4d5d0>,
#  u'specialist': <gensim.models.keyedvectors.Vocab at 0x110ba3a90>,
#  u'expediency': <gensim.models.keyedvectors.Vocab at 0x110baef90>,
#  u'_You_': <gensim.models.keyedvectors.Vocab at 0x111c9da50>,
#  u'unexpectedly': <gensim.models.keyedvectors.Vocab at 0x110baefd0>,
#  u'goodnight': <gensim.models.keyedvectors.Vocab at 0x110bb4050>,
#  u'result': <gensim.models.keyedvectors.Vocab at 0x110bb4090>,
#  u'straits': <gensim.models.keyedvectors.Vocab at 0x110c115d0>,
#  u'fail': <gensim.models.keyedvectors.Vocab at 0x111f4d650>,
#  u'hero': <gensim.models.keyedvectors.Vocab at 0x110ba3ad0>,
#  u'fain': <gensim.models.keyedvectors.Vocab at 0x111f4d690>,
#  u'resigned': <gensim.models.keyedvectors.Vocab at 0x1091fbcd0>,
#  u'skulls': <gensim.models.keyedvectors.Vocab at 0x10923d750>,
#  u'best': <gensim.models.keyedvectors.Vocab at 0x111f4d6d0>,
#  u'pricking': <gensim.models.keyedvectors.Vocab at 0x1091fbd10>,
#  u'Baalim': <gensim.models.keyedvectors.Vocab at 0x111c9da90>,
#  u'Trueman': <gensim.models.keyedvectors.Vocab at 0x1091fbd50>,
#  u'lots': <gensim.models.keyedvectors.Vocab at 0x111c9dad0>,
#  u'reporter': <gensim.models.keyedvectors.Vocab at 0x110ba3b10>,
#  u'rings': <gensim.models.keyedvectors.Vocab at 0x1091fbd90>,
#  u'solicitude': <gensim.models.keyedvectors.Vocab at 0x1091fbdd0>,
#  u'Purim': <gensim.models.keyedvectors.Vocab at 0x1091fbe10>,
#  u'loth': <gensim.models.keyedvectors.Vocab at 0x111c9db10>,
#  u'unalterable': <gensim.models.keyedvectors.Vocab at 0x111f4d750>,
#  u'Cush': <gensim.models.keyedvectors.Vocab at 0x111f4d790>,
#  u'poyson': <gensim.models.keyedvectors.Vocab at 0x110c11b10>,
#  u'Capernaum': <gensim.models.keyedvectors.Vocab at 0x111f4d7d0>,
#  u'preserve': <gensim.models.keyedvectors.Vocab at 0x111f4d810>,
#  u'claws': <gensim.models.keyedvectors.Vocab at 0x111f4d850>,
#  u'never': <gensim.models.keyedvectors.Vocab at 0x111e7d610>,
#  u'extend': <gensim.models.keyedvectors.Vocab at 0x111c9db90>,
#  u'nature': <gensim.models.keyedvectors.Vocab at 0x111c9dbd0>,
#  u'rolled': <gensim.models.keyedvectors.Vocab at 0x110bb4190>,
#  u'ask': <gensim.models.keyedvectors.Vocab at 0x111e51e50>,
#  u'twinkling': <gensim.models.keyedvectors.Vocab at 0x111f4d8d0>,
#  u'extent': <gensim.models.keyedvectors.Vocab at 0x111c9dc50>,
#  u'defiance': <gensim.models.keyedvectors.Vocab at 0x1091fbed0>,
#  u'debt': <gensim.models.keyedvectors.Vocab at 0x1091fbf10>,
#  u'tyranny': <gensim.models.keyedvectors.Vocab at 0x111c9dcd0>,
#  u'accident': <gensim.models.keyedvectors.Vocab at 0x110bb4210>,
#  u'cuffs': <gensim.models.keyedvectors.Vocab at 0x111cd4310>,
#  u'brown': <gensim.models.keyedvectors.Vocab at 0x110c17b10>,
#  u'disdain': <gensim.models.keyedvectors.Vocab at 0x1091fbf90>,
#  u'corrupted': <gensim.models.keyedvectors.Vocab at 0x1091b3050>,
#  u'country': <gensim.models.keyedvectors.Vocab at 0x1091fbfd0>,
#  u'pits': <gensim.models.keyedvectors.Vocab at 0x111cea910>,
#  u'adventures': <gensim.models.keyedvectors.Vocab at 0x111f4d950>,
#  u'incense': <gensim.models.keyedvectors.Vocab at 0x111c9dd10>,
#  u'Laura': <gensim.models.keyedvectors.Vocab at 0x111c9dd50>,
#  u'estates': <gensim.models.keyedvectors.Vocab at 0x111f4d990>,
#  u'planned': <gensim.models.keyedvectors.Vocab at 0x109200090>,
#  u'dents': <gensim.models.keyedvectors.Vocab at 0x111f4d9d0>,
#  u'blooming': <gensim.models.keyedvectors.Vocab at 0x110c06350>,
#  u'argue': <gensim.models.keyedvectors.Vocab at 0x109200110>,
#  u'adapted': <gensim.models.keyedvectors.Vocab at 0x111f4da10>,
#  u'asked': <gensim.models.keyedvectors.Vocab at 0x110bb4350>,
#  u'jack': <gensim.models.keyedvectors.Vocab at 0x109303b90>,
#  u'and': <gensim.models.keyedvectors.Vocab at 0x110bb4390>,
#  u'mortified': <gensim.models.keyedvectors.Vocab at 0x111c9dd90>,
#  u'poison': <gensim.models.keyedvectors.Vocab at 0x109303f10>,
#  u'fringed': <gensim.models.keyedvectors.Vocab at 0x110c64350>,
#  u'vail': <gensim.models.keyedvectors.Vocab at 0x111f4da90>,
#  u'vain': <gensim.models.keyedvectors.Vocab at 0x111f4dad0>,
#  u'revealeth': <gensim.models.keyedvectors.Vocab at 0x111cd4390>,
#  u'active': <gensim.models.keyedvectors.Vocab at 0x110c5e6d0>,
#  u'gleaming': <gensim.models.keyedvectors.Vocab at 0x109200190>,
#  u'infants': <gensim.models.keyedvectors.Vocab at 0x1091f0290>,
#  u'framework': <gensim.models.keyedvectors.Vocab at 0x110c27890>,
#  u'Ohio': <gensim.models.keyedvectors.Vocab at 0x10917c890>,
#  u'contentious': <gensim.models.keyedvectors.Vocab at 0x109269f90>,
#  u'humming': <gensim.models.keyedvectors.Vocab at 0x111c9ddd0>,
#  u'grazing': <gensim.models.keyedvectors.Vocab at 0x109200210>,
#  u'Instantly': <gensim.models.keyedvectors.Vocab at 0x111c9de10>,
#  u'signals': <gensim.models.keyedvectors.Vocab at 0x110be5450>,
#  u'shouting': <gensim.models.keyedvectors.Vocab at 0x109177d90>,
#  u'useth': <gensim.models.keyedvectors.Vocab at 0x111cea390>,
#  u'remained': <gensim.models.keyedvectors.Vocab at 0x110c227d0>,
#  u'fro': <gensim.models.keyedvectors.Vocab at 0x111c9de90>,
#  u'Amongst': <gensim.models.keyedvectors.Vocab at 0x111c9ded0>,
#  u'.': <gensim.models.keyedvectors.Vocab at 0x111c9df10>,
#  u'twain': <gensim.models.keyedvectors.Vocab at 0x110bb4410>,
#  u'much': <gensim.models.keyedvectors.Vocab at 0x111c9df50>,
#  u'Gideoni': <gensim.models.keyedvectors.Vocab at 0x1092002d0>,
#  u'104': <gensim.models.keyedvectors.Vocab at 0x1092a5cd0>,
#  u'Jezreelite': <gensim.models.keyedvectors.Vocab at 0x111f4dbd0>,
#  u'privilege': <gensim.models.keyedvectors.Vocab at 0x109200310>,
#  u'unleavened': <gensim.models.keyedvectors.Vocab at 0x111c9dfd0>,
#  u'fry': <gensim.models.keyedvectors.Vocab at 0x111ca2050>,
#  u'Flowers': <gensim.models.keyedvectors.Vocab at 0x111f4dc10>,
#  u'tallest': <gensim.models.keyedvectors.Vocab at 0x111ca2090>,
#  u'exactness': <gensim.models.keyedvectors.Vocab at 0x111f4dc50>,
#  u'life': <gensim.models.keyedvectors.Vocab at 0x111f4dcd0>,
#  u'rather': <gensim.models.keyedvectors.Vocab at 0x111fbb050>,
#  u'cloak': <gensim.models.keyedvectors.Vocab at 0x110bc4d90>,
#  u'spit': <gensim.models.keyedvectors.Vocab at 0x111ca20d0>,
#  u'Mothers': <gensim.models.keyedvectors.Vocab at 0x111f4dd10>,
#  u'Foole': <gensim.models.keyedvectors.Vocab at 0x1093249d0>,
#  u'verdure': <gensim.models.keyedvectors.Vocab at 0x109198710>,
#  u'onyx': <gensim.models.keyedvectors.Vocab at 0x109200350>,
#  u'punctually': <gensim.models.keyedvectors.Vocab at 0x109269fd0>,
#  u'athwart': <gensim.models.keyedvectors.Vocab at 0x109237390>,
#  u'circumcision': <gensim.models.keyedvectors.Vocab at 0x1092e7b90>,
#  u'substance': <gensim.models.keyedvectors.Vocab at 0x111f42610>,
#  u'doubts': <gensim.models.keyedvectors.Vocab at 0x111ca2110>,
#  u'worked': <gensim.models.keyedvectors.Vocab at 0x109200450>,
#  u'doth': <gensim.models.keyedvectors.Vocab at 0x109200490>,
#  u'erst': <gensim.models.keyedvectors.Vocab at 0x111f4ddd0>,
#  u'diverted': <gensim.models.keyedvectors.Vocab at 0x111f4de10>,
#  u'commerce': <gensim.models.keyedvectors.Vocab at 0x110bb44d0>,
#  u'Elisha': <gensim.models.keyedvectors.Vocab at 0x109237310>,
#  u'contemplated': <gensim.models.keyedvectors.Vocab at 0x1092004d0>,
#  u'Jael': <gensim.models.keyedvectors.Vocab at 0x109284490>,
#  u'teraphim': <gensim.models.keyedvectors.Vocab at 0x111ca2190>,
#  u'Beware': <gensim.models.keyedvectors.Vocab at 0x111ca21d0>,
#  u'contingencies': <gensim.models.keyedvectors.Vocab at 0x111ca2210>,
#  u'employ': <gensim.models.keyedvectors.Vocab at 0x111ca2250>,
#  u'Heauen': <gensim.models.keyedvectors.Vocab at 0x111ca2290>,
#  u'Beersheba': <gensim.models.keyedvectors.Vocab at 0x109200510>,
#  u'mates': <gensim.models.keyedvectors.Vocab at 0x1091b9210>,
#  u'Campbell': <gensim.models.keyedvectors.Vocab at 0x109200550>,
#  u'wonted': <gensim.models.keyedvectors.Vocab at 0x109200590>,
#  u'prostrate': <gensim.models.keyedvectors.Vocab at 0x111ca22d0>,
#  u'skirts': <gensim.models.keyedvectors.Vocab at 0x111f4de50>,
#  u'remembering': <gensim.models.keyedvectors.Vocab at 0x110bb4510>,
#  u'silken': <gensim.models.keyedvectors.Vocab at 0x109200610>,
#  u'Both': <gensim.models.keyedvectors.Vocab at 0x10922ce10>,
#  u'equator': <gensim.models.keyedvectors.Vocab at 0x110bb4590>,
#  u'Innumerable': <gensim.models.keyedvectors.Vocab at 0x111ca2310>,
#  u'obeying': <gensim.models.keyedvectors.Vocab at 0x111f4de90>,
#  u'player': <gensim.models.keyedvectors.Vocab at 0x110bb4610>,
#  u'Potomac': <gensim.models.keyedvectors.Vocab at 0x111cef850>,
#  u'eighteen': <gensim.models.keyedvectors.Vocab at 0x111ca2350>,
#  u'anticipating': <gensim.models.keyedvectors.Vocab at 0x109200650>,
#  u'Sword': <gensim.models.keyedvectors.Vocab at 0x111ca23d0>,
#  u'Obededom': <gensim.models.keyedvectors.Vocab at 0x109200690>,
#  u'bounteous': <gensim.models.keyedvectors.Vocab at 0x10924da10>,
#  u'trusted': <gensim.models.keyedvectors.Vocab at 0x111f4ded0>,
#  u'languisheth': <gensim.models.keyedvectors.Vocab at 0x110bb4650>,
#  u'memorial': <gensim.models.keyedvectors.Vocab at 0x111ca2410>,
#  u'Main': <gensim.models.keyedvectors.Vocab at 0x10926e0d0>,
#  u'severity': <gensim.models.keyedvectors.Vocab at 0x1092006d0>,
#  u'credit': <gensim.models.keyedvectors.Vocab at 0x1092a5dd0>,
#  u'things': <gensim.models.keyedvectors.Vocab at 0x110bb4690>,
#  u'reflectively': <gensim.models.keyedvectors.Vocab at 0x110bb46d0>,
#  u'woollen': <gensim.models.keyedvectors.Vocab at 0x109200750>,
#  u'shipwrecked': <gensim.models.keyedvectors.Vocab at 0x110bb4750>,
#  u'rebellion': <gensim.models.keyedvectors.Vocab at 0x110bb4790>,
#  u'greefe': <gensim.models.keyedvectors.Vocab at 0x110be5590>,
#  u'swarthy': <gensim.models.keyedvectors.Vocab at 0x111f4df10>,
#  u'split': <gensim.models.keyedvectors.Vocab at 0x111ca2490>,
#  u'babies': <gensim.models.keyedvectors.Vocab at 0x111f4df50>,
#  u'big': <gensim.models.keyedvectors.Vocab at 0x110ca0250>,
#  u'principals': <gensim.models.keyedvectors.Vocab at 0x111ca24d0>,
#  u'Enoch': <gensim.models.keyedvectors.Vocab at 0x110d03f50>,
#  u'emphatic': <gensim.models.keyedvectors.Vocab at 0x1092007d0>,
#  u'eBooks': <gensim.models.keyedvectors.Vocab at 0x110bb4810>,
#  u'exertion': <gensim.models.keyedvectors.Vocab at 0x110bb4850>,
#  u'fairly': <gensim.models.keyedvectors.Vocab at 0x111f4df90>,
#  u'thereof': <gensim.models.keyedvectors.Vocab at 0x1092b0250>,
#  u'boiled': <gensim.models.keyedvectors.Vocab at 0x111ca2510>,
#  u'marches': <gensim.models.keyedvectors.Vocab at 0x111ca2550>,
#  u'acting': <gensim.models.keyedvectors.Vocab at 0x110c95250>,
#  u'tops': <gensim.models.keyedvectors.Vocab at 0x111f4dfd0>,
#  u'walkest': <gensim.models.keyedvectors.Vocab at 0x111f53050>,
#  u'Zebedee': <gensim.models.keyedvectors.Vocab at 0x110ca02d0>,
#  u'seamen': <gensim.models.keyedvectors.Vocab at 0x111f21dd0>,
#  u'Hovering': <gensim.models.keyedvectors.Vocab at 0x109200890>,
#  u'saide': <gensim.models.keyedvectors.Vocab at 0x111f53090>,
#  u'supper': <gensim.models.keyedvectors.Vocab at 0x111ca2590>,
#  u'Persia': <gensim.models.keyedvectors.Vocab at 0x111ca25d0>,
#  u'pioneers': <gensim.models.keyedvectors.Vocab at 0x111f530d0>,
#  u'haggard': <gensim.models.keyedvectors.Vocab at 0x1092008d0>,
#  u'tune': <gensim.models.keyedvectors.Vocab at 0x110bb48d0>,
#  u'intrusion': <gensim.models.keyedvectors.Vocab at 0x111f53110>,
#  u'peremptory': <gensim.models.keyedvectors.Vocab at 0x111cf5790>,
#  u'fatal': <gensim.models.keyedvectors.Vocab at 0x110ca64d0>,
#  u'stretcheth': <gensim.models.keyedvectors.Vocab at 0x110c64250>,
#  u'echoed': <gensim.models.keyedvectors.Vocab at 0x110bb4910>,
#  u'dynamiter': <gensim.models.keyedvectors.Vocab at 0x1091e5f10>,
#  u'stillness': <gensim.models.keyedvectors.Vocab at 0x111cf5b50>,
#  u'coldness': <gensim.models.keyedvectors.Vocab at 0x111f53150>,
#  u'Cease': <gensim.models.keyedvectors.Vocab at 0x111f53190>,
#  u'Table': <gensim.models.keyedvectors.Vocab at 0x111ca2650>,
#  u'milliner': <gensim.models.keyedvectors.Vocab at 0x109253c50>,
#  u'Perizzites': <gensim.models.keyedvectors.Vocab at 0x109200950>,
#  u'fittest': <gensim.models.keyedvectors.Vocab at 0x111f531d0>,
#  u'benignity': <gensim.models.keyedvectors.Vocab at 0x111ca2690>,
#  u'opinions': <gensim.models.keyedvectors.Vocab at 0x111f53210>,
#  u'outlived': <gensim.models.keyedvectors.Vocab at 0x111ca26d0>,
#  u'bellow': <gensim.models.keyedvectors.Vocab at 0x111ca2710>,
#  u'Russell': <gensim.models.keyedvectors.Vocab at 0x111f53250>,
#  u'sleeps': <gensim.models.keyedvectors.Vocab at 0x109200a10>,
#  u'THAT': <gensim.models.keyedvectors.Vocab at 0x109200a50>,
#  u'masons': <gensim.models.keyedvectors.Vocab at 0x111f53290>,
#  u'sleepy': <gensim.models.keyedvectors.Vocab at 0x109200ad0>,
#  u'forsaken': <gensim.models.keyedvectors.Vocab at 0x111f532d0>,
#  u'sleepe': <gensim.models.keyedvectors.Vocab at 0x111cfa110>,
#  u'disguise': <gensim.models.keyedvectors.Vocab at 0x111f53310>,
#  u'maketh': <gensim.models.keyedvectors.Vocab at 0x111ca2790>,
#  u'groweth': <gensim.models.keyedvectors.Vocab at 0x111f53390>,
#  u'exclaiming': <gensim.models.keyedvectors.Vocab at 0x110bb4a50>,
#  u'plight': <gensim.models.keyedvectors.Vocab at 0x111f533d0>,
#  u'divination': <gensim.models.keyedvectors.Vocab at 0x109200b50>,
#  u'succeeding': <gensim.models.keyedvectors.Vocab at 0x110bb4ad0>,
#  u'Happy': <gensim.models.keyedvectors.Vocab at 0x111ca27d0>,
#  u'Eternity': <gensim.models.keyedvectors.Vocab at 0x111ca2810>,
#  u'orgies': <gensim.models.keyedvectors.Vocab at 0x110cc1590>,
#  u'spectacles': <gensim.models.keyedvectors.Vocab at 0x109200bd0>,
#  u'classification': <gensim.models.keyedvectors.Vocab at 0x110ba3d90>,
#  u'Offer': <gensim.models.keyedvectors.Vocab at 0x109200c10>,
#  u'ease': <gensim.models.keyedvectors.Vocab at 0x110bb4b50>,
#  u'had': <gensim.models.keyedvectors.Vocab at 0x111ca2890>,
#  u'emphasis': <gensim.models.keyedvectors.Vocab at 0x1091b9350>,
#  u'Methuselah': <gensim.models.keyedvectors.Vocab at 0x10925e550>,
#  u'hay': <gensim.models.keyedvectors.Vocab at 0x111ca28d0>,
#  u'disparity': <gensim.models.keyedvectors.Vocab at 0x109200c50>,
#  u'Nahshon': <gensim.models.keyedvectors.Vocab at 0x111ca2910>,
#  u'beloved': <gensim.models.keyedvectors.Vocab at 0x111ca2950>,
#  u'prison': <gensim.models.keyedvectors.Vocab at 0x110bb4bd0>,
#  u'hap': <gensim.models.keyedvectors.Vocab at 0x111ca2990>,
#  u'shoemaker': <gensim.models.keyedvectors.Vocab at 0x110bb4c10>,
#  u'has': <gensim.models.keyedvectors.Vocab at 0x111ca29d0>,
#  u'espoused': <gensim.models.keyedvectors.Vocab at 0x111cfaa90>,
#  u'hav': <gensim.models.keyedvectors.Vocab at 0x111ca2a50>,
#  u'abashed': <gensim.models.keyedvectors.Vocab at 0x111f53490>,
#  u'elevation': <gensim.models.keyedvectors.Vocab at 0x109200d10>,
#  u'casually': <gensim.models.keyedvectors.Vocab at 0x111f534d0>,
#  u'confidentially': <gensim.models.keyedvectors.Vocab at 0x1091b9190>,
#  u'elders': <gensim.models.keyedvectors.Vocab at 0x111ca2a90>,
#  u'profiteth': <gensim.models.keyedvectors.Vocab at 0x111cfabd0>,
#  u'harpooned': <gensim.models.keyedvectors.Vocab at 0x110d14cd0>,
#  u'disagreement': <gensim.models.keyedvectors.Vocab at 0x110bb4c90>,
#  u'possible': <gensim.models.keyedvectors.Vocab at 0x111f53510>,
#  u'firmer': <gensim.models.keyedvectors.Vocab at 0x111f53550>,
#  u'possibly': <gensim.models.keyedvectors.Vocab at 0x111f53590>,
#  u'chuse': <gensim.models.keyedvectors.Vocab at 0x109200d90>,
#  u'birth': <gensim.models.keyedvectors.Vocab at 0x111f535d0>,
#  u'Missouri': <gensim.models.keyedvectors.Vocab at 0x111f53610>,
#  u'shadow': <gensim.models.keyedvectors.Vocab at 0x111ca2ad0>,
#  u'unique': <gensim.models.keyedvectors.Vocab at 0x111f53650>,
#  u'tolerable': <gensim.models.keyedvectors.Vocab at 0x109313a50>,
#  u'bushy': <gensim.models.keyedvectors.Vocab at 0x110bb4cd0>,
#  u'desire': <gensim.models.keyedvectors.Vocab at 0x109200dd0>,
#  u'Lords': <gensim.models.keyedvectors.Vocab at 0x111f53690>,
#  u'tapering': <gensim.models.keyedvectors.Vocab at 0x111f536d0>,
#  u'seek': <gensim.models.keyedvectors.Vocab at 0x110be5110>,
#  u'seaside': <gensim.models.keyedvectors.Vocab at 0x111f53710>,
#  u'Pendragon': <gensim.models.keyedvectors.Vocab at 0x109200e10>,
#  u'Claudio': <gensim.models.keyedvectors.Vocab at 0x109200e50>,
#  u'remind': <gensim.models.keyedvectors.Vocab at 0x110bb4dd0>,
#  u'pavement': <gensim.models.keyedvectors.Vocab at 0x111f53750>,
#  u'ninety': <gensim.models.keyedvectors.Vocab at 0x1092a5fd0>,
#  u'steps': <gensim.models.keyedvectors.Vocab at 0x111f53790>,
#  u'OF': <gensim.models.keyedvectors.Vocab at 0x111cd46d0>,
#  u'moral': <gensim.models.keyedvectors.Vocab at 0x110c5e990>,
#  u'effusion': <gensim.models.keyedvectors.Vocab at 0x111ca2b10>,
#  u'attorney': <gensim.models.keyedvectors.Vocab at 0x111ca2b50>,
#  u'right': <gensim.models.keyedvectors.Vocab at 0x110bb4e50>,
#  u'Gaal': <gensim.models.keyedvectors.Vocab at 0x10929a110>,
#  u'drowned': <gensim.models.keyedvectors.Vocab at 0x111e7d850>,
#  u'crowd': <gensim.models.keyedvectors.Vocab at 0x111ca2b90>,
#  u'people': <gensim.models.keyedvectors.Vocab at 0x111f537d0>,
#  u'creed': <gensim.models.keyedvectors.Vocab at 0x109200e90>,
#  u'easy': <gensim.models.keyedvectors.Vocab at 0x110bb4b90>,
#  u'crown': <gensim.models.keyedvectors.Vocab at 0x111ca2bd0>,
#  u'crows': <gensim.models.keyedvectors.Vocab at 0x111e00b50>,
#  u'sure': <gensim.models.keyedvectors.Vocab at 0x111f06610>,
#  u'Whatever': <gensim.models.keyedvectors.Vocab at 0x1092e7dd0>,
#  u'Between': <gensim.models.keyedvectors.Vocab at 0x111ca2c50>,
#  u'prick': <gensim.models.keyedvectors.Vocab at 0x10926e190>,
#  u'animate': <gensim.models.keyedvectors.Vocab at 0x110bb4ed0>,
#  u'creep': <gensim.models.keyedvectors.Vocab at 0x109200ed0>,
#  u'enemies': <gensim.models.keyedvectors.Vocab at 0x109200f10>,
#  u'Asiatic': <gensim.models.keyedvectors.Vocab at 0x111ca2c90>,
#  u'perchance': <gensim.models.keyedvectors.Vocab at 0x111ca2cd0>,
#  u'for': <gensim.models.keyedvectors.Vocab at 0x111f538d0>,
#  u'bottom': <gensim.models.keyedvectors.Vocab at 0x111ca2d10>,
#  u'inhuman': <gensim.models.keyedvectors.Vocab at 0x111ca2d50>,
#  u'fox': <gensim.models.keyedvectors.Vocab at 0x111f53910>,
#  u'plucked': <gensim.models.keyedvectors.Vocab at 0x111ca2d90>,
#  u'witty': <gensim.models.keyedvectors.Vocab at 0x110bb4f50>,
#  u'foe': <gensim.models.keyedvectors.Vocab at 0x111f53950>,
#  u'fog': <gensim.models.keyedvectors.Vocab at 0x111f53990>,
#  u'betimes': <gensim.models.keyedvectors.Vocab at 0x110bb4f90>,
#  u'summoned': <gensim.models.keyedvectors.Vocab at 0x110bb4fd0>,
#  u'Decius': <gensim.models.keyedvectors.Vocab at 0x109200f90>,
#  u'serpents': <gensim.models.keyedvectors.Vocab at 0x111f539d0>,
#  u'surging': <gensim.models.keyedvectors.Vocab at 0x1092e7e10>,
#  u'Macduffe': <gensim.models.keyedvectors.Vocab at 0x111ca2dd0>,
#  u'defileth': <gensim.models.keyedvectors.Vocab at 0x111f53a10>,
#  u'prophesieth': <gensim.models.keyedvectors.Vocab at 0x111f53a50>,
#  u'energy': <gensim.models.keyedvectors.Vocab at 0x110ced210>,
#  u'post': <gensim.models.keyedvectors.Vocab at 0x10925e590>,
#  u'picking': <gensim.models.keyedvectors.Vocab at 0x109145910>,
#  u'terraces': <gensim.models.keyedvectors.Vocab at 0x110bb90d0>,
#  u'Thine': <gensim.models.keyedvectors.Vocab at 0x111f53a90>,
#  u'shifting': <gensim.models.keyedvectors.Vocab at 0x111f53ad0>,
#  u'losing': <gensim.models.keyedvectors.Vocab at 0x109206090>,
#  u'bowing': <gensim.models.keyedvectors.Vocab at 0x110bb9150>,
#  u'Think': <gensim.models.keyedvectors.Vocab at 0x111f53b10>,
#  u'shaken': <gensim.models.keyedvectors.Vocab at 0x1092060d0>,
#  u'First': <gensim.models.keyedvectors.Vocab at 0x110bb9190>,
#  u'Suckling': <gensim.models.keyedvectors.Vocab at 0x111ca2e10>,
#  u'Zerubbabel': <gensim.models.keyedvectors.Vocab at 0x111e05a50>,
#  u'benches': <gensim.models.keyedvectors.Vocab at 0x111ca2e90>,
#  u'55': <gensim.models.keyedvectors.Vocab at 0x109313bd0>,
#  u'gleaning': <gensim.models.keyedvectors.Vocab at 0x109206110>,
#  u'dollars': <gensim.models.keyedvectors.Vocab at 0x111f53b50>,
#  u'citizens': <gensim.models.keyedvectors.Vocab at 0x111f53b90>,
#  u'o': <gensim.models.keyedvectors.Vocab at 0x109263f90>,
#  u'despair': <gensim.models.keyedvectors.Vocab at 0x111f53bd0>,
#  u'done': <gensim.models.keyedvectors.Vocab at 0x1092dcd10>,
#  u'Shake': <gensim.models.keyedvectors.Vocab at 0x111f53c10>,
#  u'lacked': <gensim.models.keyedvectors.Vocab at 0x110bb9290>,
#  u'Jethro': <gensim.models.keyedvectors.Vocab at 0x109206150>,
#  u'meddle': <gensim.models.keyedvectors.Vocab at 0x110bb9310>,
#  u'raised': <gensim.models.keyedvectors.Vocab at 0x109206190>,
#  u'sob': <gensim.models.keyedvectors.Vocab at 0x111e0b1d0>,
#  u'statements': <gensim.models.keyedvectors.Vocab at 0x110bb93d0>,
#  u'Knowledge': <gensim.models.keyedvectors.Vocab at 0x111e0b290>,
#  u'Wisedome': <gensim.models.keyedvectors.Vocab at 0x10922cc90>,
#  u'Greeks': <gensim.models.keyedvectors.Vocab at 0x1092061d0>,
#  u'Amoz': <gensim.models.keyedvectors.Vocab at 0x110c900d0>,
#  u'nought': <gensim.models.keyedvectors.Vocab at 0x111f53c90>,
#  u'Blacky': <gensim.models.keyedvectors.Vocab at 0x109206210>,
#  u'brutes': <gensim.models.keyedvectors.Vocab at 0x111f53cd0>,
#  u'son': <gensim.models.keyedvectors.Vocab at 0x109206250>,
#  u'thankful': <gensim.models.keyedvectors.Vocab at 0x111e0b550>,
#  u'beings': <gensim.models.keyedvectors.Vocab at 0x111e0b610>,
#  u'raises': <gensim.models.keyedvectors.Vocab at 0x111e0b6d0>,
#  u'sow': <gensim.models.keyedvectors.Vocab at 0x109206310>,
#  u'wrap': <gensim.models.keyedvectors.Vocab at 0x109206350>,
#  u'gardening': <gensim.models.keyedvectors.Vocab at 0x1092e7e90>,
#  u'shoots': <gensim.models.keyedvectors.Vocab at 0x111ca2f50>,
#  u'defendants': <gensim.models.keyedvectors.Vocab at 0x111f53d10>,
#  u'bows': <gensim.models.keyedvectors.Vocab at 0x110ce2fd0>,
#  u'journeying': <gensim.models.keyedvectors.Vocab at 0x110bb9490>,
#  u'Silent': <gensim.models.keyedvectors.Vocab at 0x1092320d0>,
#  u'piazza': <gensim.models.keyedvectors.Vocab at 0x110c11850>,
#  u'despised': <gensim.models.keyedvectors.Vocab at 0x111ca2f90>,
#  u'waits': <gensim.models.keyedvectors.Vocab at 0x109206390>,
#  u'suffice': <gensim.models.keyedvectors.Vocab at 0x111ca2fd0>,
#  u'constantly': <gensim.models.keyedvectors.Vocab at 0x109206410>,
#  u'Hang': <gensim.models.keyedvectors.Vocab at 0x110bb94d0>,
#  u'tame': <gensim.models.keyedvectors.Vocab at 0x111ca8050>,
#  u'avail': <gensim.models.keyedvectors.Vocab at 0x111f53d50>,
#  u'width': <gensim.models.keyedvectors.Vocab at 0x10915b390>,
#  u'grasping': <gensim.models.keyedvectors.Vocab at 0x111ca8090>,
#  u'greatness': <gensim.models.keyedvectors.Vocab at 0x111ca80d0>,
#  u'avast': <gensim.models.keyedvectors.Vocab at 0x110cede10>,
#  u'untie': <gensim.models.keyedvectors.Vocab at 0x110ba3f90>,
#  u'SONGS': <gensim.models.keyedvectors.Vocab at 0x1091b9510>,
#  u'halls': <gensim.models.keyedvectors.Vocab at 0x111f53e10>,
#  u'happy': <gensim.models.keyedvectors.Vocab at 0x111f53e50>,
#  u'perfumes': <gensim.models.keyedvectors.Vocab at 0x111ca8110>,
#  u'waistcoat': <gensim.models.keyedvectors.Vocab at 0x111ca8150>,
#  u'offer': <gensim.models.keyedvectors.Vocab at 0x110bb95d0>,
#  u'fascination': <gensim.models.keyedvectors.Vocab at 0x111f53e90>,
#  u'forming': <gensim.models.keyedvectors.Vocab at 0x110bb9610>,
#  u'tigers': <gensim.models.keyedvectors.Vocab at 0x111f53ed0>,
#  u'universes': <gensim.models.keyedvectors.Vocab at 0x110ced4d0>,
#  u'hemisphere': <gensim.models.keyedvectors.Vocab at 0x111f53f10>,
#  u'Age': <gensim.models.keyedvectors.Vocab at 0x110cd78d0>,
#  u'perfumed': <gensim.models.keyedvectors.Vocab at 0x111ca8190>,
#  u'wentest': <gensim.models.keyedvectors.Vocab at 0x110bb9690>,
#  u'squalid': <gensim.models.keyedvectors.Vocab at 0x110bb96d0>,
#  u'principles': <gensim.models.keyedvectors.Vocab at 0x110c64590>,
#  u'IT': <gensim.models.keyedvectors.Vocab at 0x110ce81d0>,
#  u'Seeing': <gensim.models.keyedvectors.Vocab at 0x110bb9710>,
#  u'congratulations': <gensim.models.keyedvectors.Vocab at 0x111ca81d0>,
#  u'humbled': <gensim.models.keyedvectors.Vocab at 0x111ca8210>,
#  u'genealogy': <gensim.models.keyedvectors.Vocab at 0x109206490>,
#  u'rippling': <gensim.models.keyedvectors.Vocab at 0x111ca8250>,
#  u'extremity': <gensim.models.keyedvectors.Vocab at 0x1092064d0>,
#  u'inside': <gensim.models.keyedvectors.Vocab at 0x109206510>,
#  u'trash': <gensim.models.keyedvectors.Vocab at 0x110ced5d0>,
#  u'devices': <gensim.models.keyedvectors.Vocab at 0x109206550>,
#  u'tell': <gensim.models.keyedvectors.Vocab at 0x111e7d990>,
#  u'WILLIAM': <gensim.models.keyedvectors.Vocab at 0x109206590>,
#  u'nicest': <gensim.models.keyedvectors.Vocab at 0x111ca8290>,
#  u'lays': <gensim.models.keyedvectors.Vocab at 0x111f53f50>,
#  u'smashed': <gensim.models.keyedvectors.Vocab at 0x111ca82d0>,
#  u'mighty': <gensim.models.keyedvectors.Vocab at 0x111f53f90>,
#  u'dues': <gensim.models.keyedvectors.Vocab at 0x111ca8350>,
#  u'passenger': <gensim.models.keyedvectors.Vocab at 0x111ca8390>,
#  u'proud': <gensim.models.keyedvectors.Vocab at 0x111f53fd0>,
#  u'disgrace': <gensim.models.keyedvectors.Vocab at 0x111ca83d0>,
#  u'Sit': <gensim.models.keyedvectors.Vocab at 0x110bb9790>,
#  ...}

# %%
len(model.wv.vocab)
# Out:
# 17011

# %%
X = model[model.wv.vocab]
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel/__main__.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   if __name__ == '__main__':

# %%
tsne = TSNE(n_components=2, n_iter=1000) # 200 is minimum iter; default is 1000

# %%
X_2d = tsne.fit_transform(X)

# %%
X_2d[0:5]
# Out:
# array([[ 0.09538241, -3.59745306],
#        [-0.1246897 ,  2.82556949],
#        [ 1.93378361,  0.38103745],
#        [-4.93608421,  0.95028064],
#        [ 1.19624988,  4.94872784]])

# %%
# create DataFrame for storing results and plotting
coords_df = pd.DataFrame(X_2d, columns=['x','y'])
coords_df['token'] = model.wv.vocab.keys()

# %%
coords_df.head()
# Out:
#           x         y   token
# 0  0.095382 -3.597453  realms
# 1 -0.124690  2.825569    Doeg
# 2  1.933784  0.381037    both
# 3 -4.936084  0.950281  yellow
# 4  1.196250  4.948728    four

# %% [markdown]
# Visualization

# %%
coords_df = pd.read_csv('raw_gutenberg_tsne.csv')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-45-7653a99bd2b1> in <module>()
# ----> 1 coords_df = pd.read_csv('raw_gutenberg_tsne.csv')
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     560                     skip_blank_lines=skip_blank_lines)
#     561
# --> 562         return _read(filepath_or_buffer, kwds)
#     563
#     564     parser_f.__name__ = name
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     313
#     314     # Create the parser.
# --> 315     parser = TextFileReader(filepath_or_buffer, **kwds)
#     316
#     317     if (nrows is not None) and (chunksize is not None):
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     643             self.options['has_index_names'] = kwds['has_index_names']
#     644
# --> 645         self._make_engine(self.engine)
#     646
#     647     def close(self):
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     797     def _make_engine(self, engine='c'):
#     798         if engine == 'c':
# --> 799             self._engine = CParserWrapper(self.f, **self.options)
#     800         else:
#     801             if engine == 'python':
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1211         kwds['allow_leading_cols'] = self.index_col is not False
#    1212
# -> 1213         self._reader = _parser.TextReader(src, **kwds)
#    1214
#    1215         # XXX
#
# pandas/parser.pyx in pandas.parser.TextReader.__cinit__ (pandas/parser.c:3427)()
#
# pandas/parser.pyx in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:6861)()
#
# IOError: File raw_gutenberg_tsne.csv does not exist

# %%
_ = coords_df.plot.scatter('x', 'y', figsize=(12,12), marker='.', s=10, alpha=0.2)

# %%
output_notebook() # output bokeh plots inline in notebook
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="cd2a40a2-890f-412e-bc63-f07836d6edad">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# Bokeh

# %%
subset_df = coords_df.sample(n=5000)

# %%
p = figure(plot_width=800, plot_height=800)
_ = p.text(x=subset_df.x, y=subset_df.y, text=subset_df.token)

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e062c00e-5847-4da8-85c8-776d5d74b665"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("e062c00e-5847-4da8-85c8-776d5d74b665").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e062c00e-5847-4da8-85c8-776d5d74b665");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e062c00e-5847-4da8-85c8-776d5d74b665' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ee6618f9-9f73-4e87-9273-0e5f434e64c3":{"roots":{"references":[{"attributes":{"overlay":{"id":"743e4af7-3a52-417f-97d6-a4de3f916452","type":"BoxAnnotation"},"plot":{"id":"89c59beb-d1a0-4350-9571-d5f50965c877","subtype":"Figure","type":"Plot"}},"id":"44ef9f49-ba9e-4d41-ac3c-852350d9498a","type":"BoxZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"743e4af7-3a52-417f-97d6-a4de3f916452","type":"BoxAnnotation"},{"attributes":{"dimension":1,"plot":{"id":"89c59beb-d1a0-4350-9571-d5f50965c877","subtype":"Figure","type":"Plot"},"ticker":{"id":"ae122f2d-3c28-4e18-9773-075e6fad4e6b","type":"BasicTicker"}},"id":"230512a4-9626-4dac-ba6b-975e8a3b1097","type":"Grid"},{"attributes":{"callback":null},"id":"49e88ada-8ab2-45ad-973a-d407d72df554","type":"DataRange1d"},{"attributes":{"formatter":{"id":"5d77c72b-9de9-4171-a87d-e4578c9752e1","type":"BasicTickFormatter"},"plot":{"id":"89c59beb-d1a0-4350-9571-d5f50965c877","subtype":"Figure","type":"Plot"},"ticker":{"id":"ae122f2d-3c28-4e18-9773-075e6fad4e6b","type":"BasicTicker"}},"id":"d2d64361-caae-4291-8a4a-e8636715ce44","type":"LinearAxis"},{"attributes":{},"id":"c40f4dec-9c11-461b-8818-85b61620e86b","type":"ToolEvents"},{"attributes":{"plot":null,"text":""},"id":"0ea96068-21ab-42dd-8428-b5e838f7c3c1","type":"Title"},{"attributes":{"plot":{"id":"89c59beb-d1a0-4350-9571-d5f50965c877","subtype":"Figure","type":"Plot"}},"id":"8806ab72-02d8-444e-b714-ca0e28b897b5","type":"HelpTool"},{"attributes":{"plot":{"id":"89c59beb-d1a0-4350-9571-d5f50965c877","subtype":"Figure","type":"Plot"}},"id":"e4f1fa94-a588-46e3-be16-d8c5df0a361d","type":"PanTool"},{"attributes":{"plot":{"id":"89c59beb-d1a0-4350-9571-d5f50965c877","subtype":"Figure","type":"Plot"}},"id":"fb3aa323-610d-4e9f-a9f6-91e06e95bbbc","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["text","y","x"],"data":{"text":["tulip","Musgrove","Ships","determinate","Tulip","85","sanity","maiden","escapeth","attract","listened","NO","Prince","punch","entrance","Lane","instincts","bequeath","Zeboim","halting","booty","spurs","jar","farce","Dashwood","quest","thought","magistrate","cutlass","irresistible","retribution","investigation","gable","landsman","materially","Jonadab","suffers","vent","dazed","natures","needy","offices","Baalhanan","blooded","furniture","splashed","starboard","attendant","absorbed","sentiment","hasten","nineteenth","traitor","ankle","inducements","usury","Washington","detailed","rightly","lowering","appearing","amusing","chocks","shreds","prophesy","impression","merciful","captives","altars","Supper","chamberlain","buyer","affords","cropped","Tophet","Elon","Kedar","Reasons","succeed","inattention","hospitable","destroying","III","seventeen","herd","WAS","must","alarming","Kohath","assayed","shed","commend","ahead","beforehand","sage","Drew","cleaving","rivals","goods","military","opposition","st","brazen","r","spar","faint","Dawlish","Gilead","fuller","shewest",".--","hears","tumble","Arkansas","contended","shade","detaining","stunning","observant","rendering","unguarded","bones","currents","occurs","poised","punctual","reclining","breaches","Eastern","release","rewarded","Senators","palsy","\",","affection","sobriety","slimy","bands","slothful","jelly","keyhole","I","Left","Somersetshire","senile","energy","aprons","Franklin","20","possesses","falls","hazel","needeth","vanities","zone","Cabaco","foorth","crimes","Ephron","plow","jerking","settled","modes","circumference","quill","unwillingness","ambition","haunted","helmeted","locked","aloes","Manet","immediately","Lie","lions","insect","enmity","henceforward","smarter","briers","scales","complicated","dawned","distinctly","reasonably","discoveries","sounds" ...
